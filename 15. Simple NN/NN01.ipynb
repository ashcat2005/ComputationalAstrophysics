# %% [markdown]
# <center>
# <img src="https://i.ibb.co/b3T5hkz/logo.png" alt="logo" border="0" width=600>

# %% [markdown]
# ---
# # 01. First Neural Network
#
#
# Eduard Larrañaga (ealarranaga@unal.edu.co)
#
# ---

# %% [markdown]
# ### Abstract
#
# In this notebook we will implement a simple neural network to represent a linear model.
#
# ---

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## The Dataset
#
# We will use the following dataset including 10 temperatures given in Celsius and Fahrenheit degrees.

# %%
celsius = np.array([-40., -30., -10., -5., 0., 8., 15., 22., 38., 50.])
fahrenheit = np.array([-40. , -22. ,  14. ,  23. ,  32. ,  46.4,  59. ,  71.6, 100.4,
       122. ])


df = pd.DataFrame(celsius, columns=['C'] )
df['F'] = fahrenheit
df
# Out:
#       C      F
# 0 -40.0  -40.0
# 1 -30.0  -22.0
# 2 -10.0   14.0
# 3  -5.0   23.0
# 4   0.0   32.0
# 5   8.0   46.4
# 6  15.0   59.0
# 7  22.0   71.6
# 8  38.0  100.4
# 9  50.0  122.0

# %% [markdown]
# ---
#
# ## Building our first neural network
#
# We will use the framwork [Keras](https://keras.io) to create the layers of the neural network. In this simple case, we will use only two layers:
#
# - The input layer with one neuron
# - The output layer with one neuron
#
# The first command creates a [Sequential Model](https://keras.io/guides/sequential_model/) in which each layer has only one input tensor and one output tensor.
#
# Then, we add the input layer with one neuron and the output as a dense later (in this case the dense characteristic just give the connection between the input and output layers).

# %%
model = tf.keras.Sequential()
model.add(tf.keras.Input(shape=(1,))) # Input layer
model.add(tf.keras.layers.Dense(1)) # Output layer

# %% [markdown]
# It is also possible to define the model defining the output layer together with the option  `input_shape=[1]`, which will create the input layer, and after defining the model with this layer.

# %%
#layer = tf.keras.layers.Dense(units=1, input_shape=[1])

#model = tf.keras.Sequential([layer])

# %% [markdown]
# Finally, it is also possible to define the model as

# %%
#model = tf.keras.Sequential()
#model.add(tf.keras.layers.Dense(1, input_shape=(1,)))

# %% [markdown]
# NOte that we have NOT included the definition of an 'activation function'. However, the model definition defines as default a 'linear activation function'.

# %% [markdown]
# ---
# The next step is to compile the model using and 'optimizer' and a 'cost' or 'loss function'.
#
# ### The Optimizer
#
# The 'optimizer' will define how is performed the adjust of weigths and bias in order to allow that the algorithm learns (and not un-learns). We have seen the simplest method based on the **Gradient descent** method in which
# \begin{equation}
# w_{t+1} = w_{t} - \alpha \frac{\partial f_C}{\partial w}
# \end{equation}
# where $\alpha$ is the learning rate.
#
# However there are other methods and/or modifications to this idea. For example, the **Momentum** method incorporates the average of past gradients to accelerate the convergence. This is given by the equation
# \begin{equation}
# w_{t+1} = w_{t} - \alpha m_t
# \end{equation}
# where
# \begin{equation}
# m_t = (1-\beta) \frac{\partial f_C}{\partial w} + \beta m_{t-1}
# \end{equation}
# and
#
# - $m_{t}$ : aggreagate of gradients at time $t$ (current time)
# - $m_{t-1}$ : aggregate of gradients at time $t-1$ (previous time)
# - $\beta$ : average parameter ($\sim 0.9$)
#
#
# The **R**oot **M**ean **S**quare **P**ropagation (**RMSP** or **RMSprop**) method takes an exponential moving average of the gradients,
# \begin{equation}
# w_{t+1} = w_{t} - \frac{\alpha_t}{(v_t + \epsilon)^{1/2}} \frac{\partial f_C}{\partial w}
# \end{equation}
# where
# \begin{equation}
# v_{t} = \beta v_{t-1} + (1-\beta) \left(\frac{\partial f_C}{\partial w}\right)^2
# \end{equation}
# is the sum of the squares of past gradients and
# - $\epsilon$ : small positive constant ($\sim 10^{-8}$)
#
#
# Keras includes the following [optimizers](https://keras.io/api/optimizers/):
#
# - SGD (Stochastic Gradient Descent)
# - RMSprop
# - Adam
# - Adadelta
# - Adagrad
# - Adamax
# - Nadam
# - Ftrl
#
# ---
#
#
#
# #### The ADAM optimizer
#
# In this network, will use the optimizer called [ADAM](https://keras.io/api/optimizers/adam/) (**ADA**ptive **M**oment Estimation) (see [arXiV:1412.6980](https://arxiv.org/abs/1412.6980)).
#
# This is one of the simpler optimizers and uses a combination of  gradient descent and momentum methods. According to its documentation, this optimizer is efficient, requires little memory and it is useful for problems with a large number of data or parameters.
#
# The only argument that we will pass to the optimizer is  `learning_rate = 0.1` (the default is 0.001), which measures how much will adjust the parameters (weigths and bias) in each epoch. If this number is very small, the adjust will be small and the algorithm will learn slowly, if the number is big, the parameters will change with big steps and the algorithm may not learn adequately.
#
# <center>
# <img src="https://media.geeksforgeeks.org/wp-content/uploads/20200909204946/performance.png" width=400 />

# %% [markdown]
# ### The Loss function
#
# The loss (or cost) is the function that measures the difference between predictions of the model and known targets. It is also the function that we want to minimize using the optimizer.
#
# Keras includes many [loss functions](https://keras.io/api/losses/) for each kind of data that is used:
#
# **Probabilistic losses**
# - BinaryCrossentropy class
# - CategoricalCrossentropy class
# - SparseCategoricalCrossentropy class
# - Poisson class
# - binary_crossentropy function
# - categorical_crossentropy function
# - sparse_categorical_crossentropy function
# - poisson function
# - KLDivergence class
# - kl_divergence function
#
# **Regression losses**
# - MeanSquaredError class
# - MeanAbsoluteError class
# - MeanAbsolutePercentageError class
# - MeanSquaredLogarithmicError class
# - CosineSimilarity class
# - mean_squared_error function
# - mean_absolute_error function
# - mean_absolute_percentage_error function
# - mean_squared_logarithmic_error function
# - cosine_similarity function
# - Huber class
# - huber function
# - LogCosh class
# - log_cosh function
#
# **Hinge losses for "maximum-margin" classification**
# - Hinge class
# - SquaredHinge class
# - CategoricalHinge class
# - hinge function
# - squared_hinge function
# - categorical_hinge function
#
# ---
#
# #### The Mean-Squared-Error function
# In this example, we will use the [mean_squared_error](https://keras.io/api/losses/regression_losses/#mean_squared_error-function) loss function, which calculates the mean of the squared errors between targets and predictions.

# %%
model.compile(
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.1),
    loss = 'mean_squared_error'
)

# %% [markdown]
# Now is time to train the model using the method [.fit()](https://keras.io/api/models/model_training_apis/).
#
# We will use the input data `'celsius'` y `'fahrenheit'`. Since this set has only 10 samples, we will use 1000 epochs to train the model.
# The argument `verbose=False` indicates that the advance in the training process won't be shown on the screen (False is recommended when working in a Jupyter notebook)

# %%
print('Entrendando...')

m_history = model.fit(celsius, fahrenheit, epochs = 1000, verbose=False)

print('Modelo entrenado!!')
# Out:
# Entrendando...
# Modelo entrenado!!

# %% [markdown]
# Once the model is trained, we can visualize the loss function during each epoch to see how the model is improving its learning. The attribute `.history` stores the information of the loss during the training process.

# %%
plt.xlabel('Epoch')
plt.ylabel('Loss Magnitude')
plt.plot(m_history.history['loss'])
#plt.yscale('log')
plt.show()

# %% [markdown]
# From this plot it is possible to note that approximately from the epoch 400, the loss function is so small that it presents no substancial changes (i.e. from the epoch 400 the algorithm foes not learn anything more).

# %% [markdown]
# ---
# Now the model has obtained the optimized parameters and is ready to be applied to new data. Using the method [.predict](https://keras.io/api/models/model_training_apis/) we can obtain the prediction for a new value. For example,

# %%
prediction = model.predict([100.0])

known_value = 212.0 #C2F(100.0)


print('Prediction = ', prediction)
print('Known value = ', known_value)
# Out:
# 1/1 [==============================] - 0s 93ms/step
# Prediction =  [[211.99026]]
# Known value =  212.0

# %% [markdown]
# Note that the prediction is congruent with the known value.
#
# ---
#
# Since this model is very simple, we can access the adjusted parameters during the training process. Hence, we use the method [.get_weights()](https://keras.io/api/layers/base_layer/) applied to the layer(s)

# %%
# Retrieves a layer from the model. In this case we have just one layer (output)
output_layer = model.get_layer(index=0)

output_layer.get_weights()
# Out:
# [array([[1.8001903]], dtype=float32), array([31.971233], dtype=float32)]

# %% [markdown]
# These values correspond to the slope, $\frac{9}{5} = 1.8$, and the intercept, $32$, of the well known transformation equation,
#
# \begin{equation}
# ºF = \frac{9}{5} ºC + 32
# \end{equation}

# %% [markdown]
# ---

# %% [markdown]
# ## A Neural Network with Multiples layers
#
# Now we will include 2 hidden layers (with 3 neurons each) and the output layer (1 neuron) in the model.

# %%
hl1 = tf.keras.layers.Dense(units=3, input_shape=[1])
hl2 = tf.keras.layers.Dense(units=3)
outl = tf.keras.layers.Dense(units=1)

model2 = tf.keras.Sequential([hl1, hl2, outl])

# %%
model2.compile(
    optimizer = tf.keras.optimizers.Adam(0.1),
    loss = 'mean_squared_error'
)

# %%
print('Entrendando...')

m_history2 = model2.fit(celsius, fahrenheit, epochs = 500, verbose=False)

print('Modelo entrenado!!')
# Out:
# Entrendando...
# Epoch 1/500
# 1/1 [==============================] - 1s 1s/step - loss: 3633.2046
# Epoch 2/500
# 1/1 [==============================] - 0s 11ms/step - loss: 2810.2847
# Epoch 3/500
# 1/1 [==============================] - 0s 11ms/step - loss: 1984.9426
# Epoch 4/500
# 1/1 [==============================] - 0s 11ms/step - loss: 1186.5974
# Epoch 5/500
# 1/1 [==============================] - 0s 14ms/step - loss: 864.1627
# Epoch 6/500
# 1/1 [==============================] - 0s 13ms/step - loss: 1410.4747
# Epoch 7/500
# 1/1 [==============================] - 0s 14ms/step - loss: 1455.9138
# Epoch 8/500
# 1/1 [==============================] - 0s 18ms/step - loss: 1053.7402
# Epoch 9/500
# 1/1 [==============================] - 0s 14ms/step - loss: 755.0049
# Epoch 10/500
# 1/1 [==============================] - 0s 20ms/step - loss: 719.0884
# Epoch 11/500
# 1/1 [==============================] - 0s 16ms/step - loss: 826.2855
# Epoch 12/500
# 1/1 [==============================] - 0s 18ms/step - loss: 916.8758
# Epoch 13/500
# 1/1 [==============================] - 0s 15ms/step - loss: 913.9276
# Epoch 14/500
# 1/1 [==============================] - 0s 15ms/step - loss: 820.2648
# Epoch 15/500
# 1/1 [==============================] - 0s 16ms/step - loss: 680.1899
# Epoch 16/500
# 1/1 [==============================] - 0s 14ms/step - loss: 551.3341
# Epoch 17/500
# 1/1 [==============================] - 0s 18ms/step - loss: 482.3748
# Epoch 18/500
# 1/1 [==============================] - 0s 23ms/step - loss: 486.9332
# Epoch 19/500
# 1/1 [==============================] - 0s 20ms/step - loss: 525.8853
# Epoch 20/500
# 1/1 [==============================] - 0s 20ms/step - loss: 533.6140
# Epoch 21/500
# 1/1 [==============================] - 0s 21ms/step - loss: 480.8520
# Epoch 22/500
# 1/1 [==============================] - 0s 26ms/step - loss: 396.0536
# Epoch 23/500
# 1/1 [==============================] - 0s 22ms/step - loss: 325.4578
# Epoch 24/500
# 1/1 [==============================] - 0s 21ms/step - loss: 291.8921
# Epoch 25/500
# 1/1 [==============================] - 0s 20ms/step - loss: 287.7893
# Epoch 26/500
# 1/1 [==============================] - 0s 17ms/step - loss: 291.1609
# Epoch 27/500
# 1/1 [==============================] - 0s 16ms/step - loss: 282.6620
# Epoch 28/500
# 1/1 [==============================] - 0s 16ms/step - loss: 254.0858
# Epoch 29/500
# 1/1 [==============================] - 0s 9ms/step - loss: 209.4077
# Epoch 30/500
# 1/1 [==============================] - 0s 8ms/step - loss: 161.4154
# Epoch 31/500
# 1/1 [==============================] - 0s 9ms/step - loss: 124.9964
# Epoch 32/500
# 1/1 [==============================] - 0s 9ms/step - loss: 107.9731
# Epoch 33/500
# 1/1 [==============================] - 0s 14ms/step - loss: 104.2754
# Epoch 34/500
# 1/1 [==============================] - 0s 18ms/step - loss: 97.8196
# Epoch 35/500
# 1/1 [==============================] - 0s 14ms/step - loss: 77.5674
# Epoch 36/500
# 1/1 [==============================] - 0s 24ms/step - loss: 48.3786
# Epoch 37/500
# 1/1 [==============================] - 0s 15ms/step - loss: 24.9047
# Epoch 38/500
# 1/1 [==============================] - 0s 16ms/step - loss: 16.6652
# Epoch 39/500
# 1/1 [==============================] - 0s 16ms/step - loss: 20.3246
# Epoch 40/500
# 1/1 [==============================] - 0s 19ms/step - loss: 24.4711
# Epoch 41/500
# 1/1 [==============================] - 0s 19ms/step - loss: 20.4860
# Epoch 42/500
# 1/1 [==============================] - 0s 22ms/step - loss: 9.8091
# Epoch 43/500
# 1/1 [==============================] - 0s 21ms/step - loss: 1.9014
# Epoch 44/500
# 1/1 [==============================] - 0s 20ms/step - loss: 4.4234
# Epoch 45/500
# 1/1 [==============================] - 0s 23ms/step - loss: 14.4497
# Epoch 46/500
# 1/1 [==============================] - 0s 21ms/step - loss: 21.3938
# Epoch 47/500
# 1/1 [==============================] - 0s 14ms/step - loss: 19.8734
# Epoch 48/500
# 1/1 [==============================] - 0s 20ms/step - loss: 15.4436
# Epoch 49/500
# 1/1 [==============================] - 0s 27ms/step - loss: 15.7071
# Epoch 50/500
# 1/1 [==============================] - 0s 24ms/step - loss: 20.4722
# Epoch 51/500
# 1/1 [==============================] - 0s 22ms/step - loss: 23.4385
# Epoch 52/500
# 1/1 [==============================] - 0s 25ms/step - loss: 20.7889
# Epoch 53/500
# 1/1 [==============================] - 0s 23ms/step - loss: 15.1323
# Epoch 54/500
# 1/1 [==============================] - 0s 12ms/step - loss: 11.4448
# Epoch 55/500
# 1/1 [==============================] - 0s 12ms/step - loss: 11.0960
# Epoch 56/500
# 1/1 [==============================] - 0s 16ms/step - loss: 11.0651
# Epoch 57/500
# 1/1 [==============================] - 0s 19ms/step - loss: 8.5786
# Epoch 58/500
# 1/1 [==============================] - 0s 17ms/step - loss: 4.6013
# Epoch 59/500
# 1/1 [==============================] - 0s 13ms/step - loss: 1.9997
# Epoch 60/500
# 1/1 [==============================] - 0s 11ms/step - loss: 1.8344
# Epoch 61/500
# 1/1 [==============================] - 0s 20ms/step - loss: 2.6181
# Epoch 62/500
# 1/1 [==============================] - 0s 20ms/step - loss: 2.5183
# Epoch 63/500
# 1/1 [==============================] - 0s 19ms/step - loss: 1.3329
# Epoch 64/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.3022
# Epoch 65/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.4671
# Epoch 66/500
# 1/1 [==============================] - 0s 18ms/step - loss: 1.5285
# Epoch 67/500
# 1/1 [==============================] - 0s 16ms/step - loss: 2.3430
# Epoch 68/500
# 1/1 [==============================] - 0s 20ms/step - loss: 2.2893
# Epoch 69/500
# 1/1 [==============================] - 0s 21ms/step - loss: 1.8254
# Epoch 70/500
# 1/1 [==============================] - 0s 22ms/step - loss: 1.7318
# Epoch 71/500
# 1/1 [==============================] - 0s 28ms/step - loss: 2.1564
# Epoch 72/500
# 1/1 [==============================] - 0s 33ms/step - loss: 2.5682
# Epoch 73/500
# 1/1 [==============================] - 0s 20ms/step - loss: 2.4698
# Epoch 74/500
# 1/1 [==============================] - 0s 25ms/step - loss: 1.9418
# Epoch 75/500
# 1/1 [==============================] - 0s 23ms/step - loss: 1.4691
# Epoch 76/500
# 1/1 [==============================] - 0s 26ms/step - loss: 1.3482
# Epoch 77/500
# 1/1 [==============================] - 0s 25ms/step - loss: 1.3902
# Epoch 78/500
# 1/1 [==============================] - 0s 23ms/step - loss: 1.2303
# Epoch 79/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.8075
# Epoch 80/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4083
# Epoch 81/500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2761
# Epoch 82/500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3314
# Epoch 83/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3259
# Epoch 84/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.1723
# Epoch 85/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0222
# Epoch 86/500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0357
# Epoch 87/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.1698
# Epoch 88/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2546
# Epoch 89/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.2237
# Epoch 90/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1757
# Epoch 91/500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.2095
# Epoch 92/500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.2894
# Epoch 93/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3124
# Epoch 94/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2546
# Epoch 95/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1898
# Epoch 96/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1770
# Epoch 97/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1868
# Epoch 98/500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.1601
# Epoch 99/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0967
# Epoch 100/500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0487
# Epoch 101/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0428
# Epoch 102/500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0499
# Epoch 103/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0361
# Epoch 104/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0094
# Epoch 105/500
# 1/1 [==============================] - 0s 11ms/step - loss: 8.7353e-04
# Epoch 106/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0165
# Epoch 107/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0322
# Epoch 108/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0306
# Epoch 109/500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0229
# Epoch 110/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0265
# Epoch 111/500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0386
# Epoch 112/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0432
# Epoch 113/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0355
# Epoch 114/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0268
# Epoch 115/500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0260
# Epoch 116/500
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0276
# Epoch 117/500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0227
# Epoch 118/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0131
# Epoch 119/500
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0073
# Epoch 120/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0074
# Epoch 121/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0076
# Epoch 122/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0040
# Epoch 123/500
# 1/1 [==============================] - 0s 16ms/step - loss: 3.4303e-04
# Epoch 124/500
# 1/1 [==============================] - 0s 10ms/step - loss: 8.4514e-04
# Epoch 125/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0037
# Epoch 126/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0046
# Epoch 127/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0034
# Epoch 128/500
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0032
# Epoch 129/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0051
# Epoch 130/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0064
# Epoch 131/500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0056
# Epoch 132/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0042
# Epoch 133/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0040
# Epoch 134/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0044
# Epoch 135/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0037
# Epoch 136/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0021
# Epoch 137/500
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0012
# Epoch 138/500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0013
# Epoch 139/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0012
# Epoch 140/500
# 1/1 [==============================] - 0s 16ms/step - loss: 5.1793e-04
# Epoch 141/500
# 1/1 [==============================] - 0s 15ms/step - loss: 1.2290e-05
# Epoch 142/500
# 1/1 [==============================] - 0s 13ms/step - loss: 2.4650e-04
# Epoch 143/500
# 1/1 [==============================] - 0s 12ms/step - loss: 6.6476e-04
# Epoch 144/500
# 1/1 [==============================] - 0s 19ms/step - loss: 6.4080e-04
# Epoch 145/500
# 1/1 [==============================] - 0s 14ms/step - loss: 4.3960e-04
# Epoch 146/500
# 1/1 [==============================] - 0s 19ms/step - loss: 5.8564e-04
# Epoch 147/500
# 1/1 [==============================] - 0s 16ms/step - loss: 9.3467e-04
# Epoch 148/500
# 1/1 [==============================] - 0s 12ms/step - loss: 9.9599e-04
# Epoch 149/500
# 1/1 [==============================] - 0s 21ms/step - loss: 7.6788e-04
# Epoch 150/500
# 1/1 [==============================] - 0s 15ms/step - loss: 6.4812e-04
# Epoch 151/500
# 1/1 [==============================] - 0s 20ms/step - loss: 7.2223e-04
# Epoch 152/500
# 1/1 [==============================] - 0s 21ms/step - loss: 6.9330e-04
# Epoch 153/500
# 1/1 [==============================] - 0s 21ms/step - loss: 4.5399e-04
# Epoch 154/500
# 1/1 [==============================] - 0s 24ms/step - loss: 2.4876e-04
# Epoch 155/500
# 1/1 [==============================] - 0s 19ms/step - loss: 2.2803e-04
# Epoch 156/500
# 1/1 [==============================] - 0s 22ms/step - loss: 2.3226e-04
# Epoch 157/500
# 1/1 [==============================] - 0s 20ms/step - loss: 1.2189e-04
# Epoch 158/500
# 1/1 [==============================] - 0s 39ms/step - loss: 1.0571e-05
# Epoch 159/500
# 1/1 [==============================] - 0s 23ms/step - loss: 3.0559e-05
# Epoch 160/500
# 1/1 [==============================] - 0s 19ms/step - loss: 1.0417e-04
# Epoch 161/500
# 1/1 [==============================] - 0s 16ms/step - loss: 1.0429e-04
# Epoch 162/500
# 1/1 [==============================] - 0s 15ms/step - loss: 6.7105e-05
# Epoch 163/500
# 1/1 [==============================] - 0s 20ms/step - loss: 9.2776e-05
# Epoch 164/500
# 1/1 [==============================] - 0s 15ms/step - loss: 1.5613e-04
# Epoch 165/500
# 1/1 [==============================] - 0s 16ms/step - loss: 1.6578e-04
# Epoch 166/500
# 1/1 [==============================] - 0s 12ms/step - loss: 1.2662e-04
# Epoch 167/500
# 1/1 [==============================] - 0s 15ms/step - loss: 1.1288e-04
# Epoch 168/500
# 1/1 [==============================] - 0s 18ms/step - loss: 1.2928e-04
# Epoch 169/500
# 1/1 [==============================] - 0s 21ms/step - loss: 1.1798e-04
# Epoch 170/500
# 1/1 [==============================] - 0s 13ms/step - loss: 7.2468e-05
# Epoch 171/500
# 1/1 [==============================] - 0s 15ms/step - loss: 4.3461e-05
# Epoch 172/500
# 1/1 [==============================] - 0s 15ms/step - loss: 4.4852e-05
# Epoch 173/500
# 1/1 [==============================] - 0s 22ms/step - loss: 3.9256e-05
# Epoch 174/500
# 1/1 [==============================] - 0s 16ms/step - loss: 1.4430e-05
# Epoch 175/500
# 1/1 [==============================] - 0s 19ms/step - loss: 8.3391e-07
# Epoch 176/500
# 1/1 [==============================] - 0s 17ms/step - loss: 1.0976e-05
# Epoch 177/500
# 1/1 [==============================] - 0s 22ms/step - loss: 1.9865e-05
# Epoch 178/500
# 1/1 [==============================] - 0s 16ms/step - loss: 1.3867e-05
# Epoch 179/500
# 1/1 [==============================] - 0s 17ms/step - loss: 1.1144e-05
# Epoch 180/500
# 1/1 [==============================] - 0s 20ms/step - loss: 2.1775e-05
# Epoch 181/500
# 1/1 [==============================] - 0s 13ms/step - loss: 2.9950e-05
# Epoch 182/500
# 1/1 [==============================] - 0s 15ms/step - loss: 2.5550e-05
# Epoch 183/500
# 1/1 [==============================] - 0s 17ms/step - loss: 2.0195e-05
# Epoch 184/500
# 1/1 [==============================] - 0s 21ms/step - loss: 2.2618e-05
# Epoch 185/500
# 1/1 [==============================] - 0s 23ms/step - loss: 2.3671e-05
# Epoch 186/500
# 1/1 [==============================] - 0s 19ms/step - loss: 1.6610e-05
# Epoch 187/500
# 1/1 [==============================] - 0s 20ms/step - loss: 9.4210e-06
# Epoch 188/500
# 1/1 [==============================] - 0s 20ms/step - loss: 8.6043e-06
# Epoch 189/500
# 1/1 [==============================] - 0s 20ms/step - loss: 8.3922e-06
# Epoch 190/500
# 1/1 [==============================] - 0s 14ms/step - loss: 4.0170e-06
# Epoch 191/500
# 1/1 [==============================] - 0s 15ms/step - loss: 3.8625e-07
# Epoch 192/500
# 1/1 [==============================] - 0s 21ms/step - loss: 1.6047e-06
# Epoch 193/500
# 1/1 [==============================] - 0s 19ms/step - loss: 3.5166e-06
# Epoch 194/500
# 1/1 [==============================] - 0s 25ms/step - loss: 2.5546e-06
# Epoch 195/500
# 1/1 [==============================] - 0s 17ms/step - loss: 1.7650e-06
# Epoch 196/500
# 1/1 [==============================] - 0s 27ms/step - loss: 3.7048e-06
# Epoch 197/500
# 1/1 [==============================] - 0s 26ms/step - loss: 5.4442e-06
# Epoch 198/500
# 1/1 [==============================] - 0s 20ms/step - loss: 4.7103e-06
# Epoch 199/500
# 1/1 [==============================] - 0s 32ms/step - loss: 3.7614e-06
# Epoch 200/500
# 1/1 [==============================] - 0s 18ms/step - loss: 4.3324e-06
# Epoch 201/500
# 1/1 [==============================] - 0s 19ms/step - loss: 4.5381e-06
# Epoch 202/500
# 1/1 [==============================] - 0s 26ms/step - loss: 3.1194e-06
# Epoch 203/500
# 1/1 [==============================] - 0s 16ms/step - loss: 1.8370e-06
# Epoch 204/500
# 1/1 [==============================] - 0s 24ms/step - loss: 1.7894e-06
# Epoch 205/500
# 1/1 [==============================] - 0s 26ms/step - loss: 1.6168e-06
# Epoch 206/500
# 1/1 [==============================] - 0s 17ms/step - loss: 6.5096e-07
# Epoch 207/500
# 1/1 [==============================] - 0s 24ms/step - loss: 8.3599e-08
# Epoch 208/500
# 1/1 [==============================] - 0s 19ms/step - loss: 4.3249e-07
# Epoch 209/500
# 1/1 [==============================] - 0s 21ms/step - loss: 6.6707e-07
# Epoch 210/500
# 1/1 [==============================] - 0s 35ms/step - loss: 3.6172e-07
# Epoch 211/500
# 1/1 [==============================] - 0s 15ms/step - loss: 3.6939e-07
# Epoch 212/500
# 1/1 [==============================] - 0s 15ms/step - loss: 8.3607e-07
# Epoch 213/500
# 1/1 [==============================] - 0s 17ms/step - loss: 1.0290e-06
# Epoch 214/500
# 1/1 [==============================] - 0s 117ms/step - loss: 8.0018e-07
# Epoch 215/500
# 1/1 [==============================] - 0s 67ms/step - loss: 7.5338e-07
# Epoch 216/500
# 1/1 [==============================] - 0s 41ms/step - loss: 9.1634e-07
# Epoch 217/500
# 1/1 [==============================] - 0s 48ms/step - loss: 8.1330e-07
# Epoch 218/500
# 1/1 [==============================] - 0s 41ms/step - loss: 4.8952e-07
# Epoch 219/500
# 1/1 [==============================] - 0s 43ms/step - loss: 3.6300e-07
# Epoch 220/500
# 1/1 [==============================] - 0s 52ms/step - loss: 3.8287e-07
# Epoch 221/500
# 1/1 [==============================] - 0s 45ms/step - loss: 2.4884e-07
# Epoch 222/500
# 1/1 [==============================] - 0s 37ms/step - loss: 5.0510e-08
# Epoch 223/500
# 1/1 [==============================] - 0s 40ms/step - loss: 4.7499e-08
# Epoch 224/500
# 1/1 [==============================] - 0s 41ms/step - loss: 1.3339e-07
# Epoch 225/500
# 1/1 [==============================] - 0s 37ms/step - loss: 9.7913e-08
# Epoch 226/500
# 1/1 [==============================] - 0s 33ms/step - loss: 4.9150e-08
# Epoch 227/500
# 1/1 [==============================] - 0s 49ms/step - loss: 1.2848e-07
# Epoch 228/500
# 1/1 [==============================] - 0s 40ms/step - loss: 2.0383e-07
# Epoch 229/500
# 1/1 [==============================] - 0s 40ms/step - loss: 1.7365e-07
# Epoch 230/500
# 1/1 [==============================] - 0s 39ms/step - loss: 1.4535e-07
# Epoch 231/500
# 1/1 [==============================] - 0s 29ms/step - loss: 1.7923e-07
# Epoch 232/500
# 1/1 [==============================] - 0s 39ms/step - loss: 1.8372e-07
# Epoch 233/500
# 1/1 [==============================] - 0s 38ms/step - loss: 1.1895e-07
# Epoch 234/500
# 1/1 [==============================] - 0s 41ms/step - loss: 7.8371e-08
# Epoch 235/500
# 1/1 [==============================] - 0s 20ms/step - loss: 8.6540e-08
# Epoch 236/500
# 1/1 [==============================] - 0s 22ms/step - loss: 6.6227e-08
# Epoch 237/500
# 1/1 [==============================] - 0s 31ms/step - loss: 1.7015e-08
# Epoch 238/500
# 1/1 [==============================] - 0s 40ms/step - loss: 1.0192e-08
# Epoch 239/500
# 1/1 [==============================] - 0s 33ms/step - loss: 2.8849e-08
# Epoch 240/500
# 1/1 [==============================] - 0s 34ms/step - loss: 2.2904e-08
# Epoch 241/500
# 1/1 [==============================] - 0s 34ms/step - loss: 8.6003e-09
# Epoch 242/500
# 1/1 [==============================] - 0s 33ms/step - loss: 2.3798e-08
# Epoch 243/500
# 1/1 [==============================] - 0s 34ms/step - loss: 4.3678e-08
# Epoch 244/500
# 1/1 [==============================] - 0s 31ms/step - loss: 3.5721e-08
# Epoch 245/500
# 1/1 [==============================] - 0s 33ms/step - loss: 2.9565e-08
# Epoch 246/500
# 1/1 [==============================] - 0s 25ms/step - loss: 3.9537e-08
# Epoch 247/500
# 1/1 [==============================] - 0s 28ms/step - loss: 4.0258e-08
# Epoch 248/500
# 1/1 [==============================] - 0s 37ms/step - loss: 2.5045e-08
# Epoch 249/500
# 1/1 [==============================] - 0s 22ms/step - loss: 1.6937e-08
# Epoch 250/500
# 1/1 [==============================] - 0s 25ms/step - loss: 1.9928e-08
# Epoch 251/500
# 1/1 [==============================] - 0s 31ms/step - loss: 1.4946e-08
# Epoch 252/500
# 1/1 [==============================] - 0s 17ms/step - loss: 3.7756e-09
# Epoch 253/500
# 1/1 [==============================] - 0s 20ms/step - loss: 2.7190e-09
# Epoch 254/500
# 1/1 [==============================] - 0s 31ms/step - loss: 6.8059e-09
# Epoch 255/500
# 1/1 [==============================] - 0s 16ms/step - loss: 5.3003e-09
# Epoch 256/500
# 1/1 [==============================] - 0s 19ms/step - loss: 1.6801e-09
# Epoch 257/500
# 1/1 [==============================] - 0s 15ms/step - loss: 5.8233e-09
# Epoch 258/500
# 1/1 [==============================] - 0s 15ms/step - loss: 1.0640e-08
# Epoch 259/500
# 1/1 [==============================] - 0s 18ms/step - loss: 7.8995e-09
# Epoch 260/500
# 1/1 [==============================] - 0s 21ms/step - loss: 6.5681e-09
# Epoch 261/500
# 1/1 [==============================] - 0s 24ms/step - loss: 9.6193e-09
# Epoch 262/500
# 1/1 [==============================] - 0s 15ms/step - loss: 8.8858e-09
# Epoch 263/500
# 1/1 [==============================] - 0s 17ms/step - loss: 4.7138e-09
# Epoch 264/500
# 1/1 [==============================] - 0s 13ms/step - loss: 3.9370e-09
# Epoch 265/500
# 1/1 [==============================] - 0s 13ms/step - loss: 4.3267e-09
# Epoch 266/500
# 1/1 [==============================] - 0s 12ms/step - loss: 2.6602e-09
# Epoch 267/500
# 1/1 [==============================] - 0s 9ms/step - loss: 4.6930e-10
# Epoch 268/500
# 1/1 [==============================] - 0s 18ms/step - loss: 1.0787e-09
# Epoch 269/500
# 1/1 [==============================] - 0s 13ms/step - loss: 1.8925e-09
# Epoch 270/500
# 1/1 [==============================] - 0s 22ms/step - loss: 6.6866e-10
# Epoch 271/500
# 1/1 [==============================] - 0s 17ms/step - loss: 8.2118e-10
# Epoch 272/500
# 1/1 [==============================] - 0s 19ms/step - loss: 2.0438e-09
# Epoch 273/500
# 1/1 [==============================] - 0s 28ms/step - loss: 2.3188e-09
# Epoch 274/500
# 1/1 [==============================] - 0s 19ms/step - loss: 1.3883e-09
# Epoch 275/500
# 1/1 [==============================] - 0s 20ms/step - loss: 1.9944e-09
# Epoch 276/500
# 1/1 [==============================] - 0s 15ms/step - loss: 2.1930e-09
# Epoch 277/500
# 1/1 [==============================] - 0s 23ms/step - loss: 1.4073e-09
# Epoch 278/500
# 1/1 [==============================] - 0s 9ms/step - loss: 8.7866e-10
# Epoch 279/500
# 1/1 [==============================] - 0s 15ms/step - loss: 9.9608e-10
# Epoch 280/500
# 1/1 [==============================] - 0s 13ms/step - loss: 6.2246e-10
# Epoch 281/500
# 1/1 [==============================] - 0s 18ms/step - loss: 1.5643e-10
# Epoch 282/500
# 1/1 [==============================] - 0s 13ms/step - loss: 2.0736e-10
# Epoch 283/500
# 1/1 [==============================] - 0s 17ms/step - loss: 2.3356e-10
# Epoch 284/500
# 1/1 [==============================] - 0s 17ms/step - loss: 6.2664e-11
# Epoch 285/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.4743e-10
# Epoch 286/500
# 1/1 [==============================] - 0s 11ms/step - loss: 3.5798e-10
# Epoch 287/500
# 1/1 [==============================] - 0s 10ms/step - loss: 4.0964e-10
# Epoch 288/500
# 1/1 [==============================] - 0s 18ms/step - loss: 2.2992e-10
# Epoch 289/500
# 1/1 [==============================] - 0s 18ms/step - loss: 2.1319e-10
# Epoch 290/500
# 1/1 [==============================] - 0s 13ms/step - loss: 3.2378e-10
# Epoch 291/500
# 1/1 [==============================] - 0s 12ms/step - loss: 3.2378e-10
# Epoch 292/500
# 1/1 [==============================] - 0s 11ms/step - loss: 1.9536e-10
# Epoch 293/500
# 1/1 [==============================] - 0s 14ms/step - loss: 2.2201e-10
# Epoch 294/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.9982e-10
# Epoch 295/500
# 1/1 [==============================] - 0s 16ms/step - loss: 1.9982e-10
# Epoch 296/500
# 1/1 [==============================] - 0s 20ms/step - loss: 9.4951e-11
# Epoch 297/500
# 1/1 [==============================] - 0s 31ms/step - loss: 8.7402e-11
# Epoch 298/500
# 1/1 [==============================] - 0s 9ms/step - loss: 4.8840e-11
# Epoch 299/500
# 1/1 [==============================] - 0s 16ms/step - loss: 9.1859e-12
# Epoch 300/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.6098e-11
# Epoch 301/500
# 1/1 [==============================] - 0s 9ms/step - loss: 2.5193e-11
# Epoch 302/500
# 1/1 [==============================] - 0s 9ms/step - loss: 2.1100e-11
# Epoch 303/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.5280e-11
# Epoch 304/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1732e-11
# Epoch 305/500
# 1/1 [==============================] - 0s 12ms/step - loss: 1.1732e-11
# Epoch 306/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.6098e-11
# Epoch 307/500
# 1/1 [==============================] - 0s 8ms/step - loss: 1.6098e-11
# Epoch 308/500
# 1/1 [==============================] - 0s 12ms/step - loss: 1.1732e-11
# Epoch 309/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.7553e-11
# Epoch 310/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.5734e-11
# Epoch 311/500
# 1/1 [==============================] - 0s 13ms/step - loss: 1.5280e-11
# Epoch 312/500
# 1/1 [==============================] - 0s 12ms/step - loss: 2.6921e-11
# Epoch 313/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.5280e-11
# Epoch 314/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.7553e-11
# Epoch 315/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1732e-11
# Epoch 316/500
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1732e-11
# Epoch 317/500
# 1/1 [==============================] - 0s 35ms/step - loss: 1.1732e-11
# Epoch 318/500
# 1/1 [==============================] - 0s 23ms/step - loss: 1.1732e-11
# Epoch 319/500
# 1/1 [==============================] - 0s 25ms/step - loss: 1.1732e-11
# Epoch 320/500
# 1/1 [==============================] - 0s 18ms/step - loss: 1.5734e-11
# Epoch 321/500
# 1/1 [==============================] - 0s 16ms/step - loss: 2.1100e-11
# Epoch 322/500
# 1/1 [==============================] - 0s 9ms/step - loss: 2.1100e-11
# Epoch 323/500
# 1/1 [==============================] - 0s 10ms/step - loss: 2.1100e-11
# Epoch 324/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.7553e-11
# Epoch 325/500
# 1/1 [==============================] - 0s 13ms/step - loss: 1.7189e-11
# Epoch 326/500
# 1/1 [==============================] - 0s 28ms/step - loss: 1.6098e-11
# Epoch 327/500
# 1/1 [==============================] - 0s 13ms/step - loss: 1.6098e-11
# Epoch 328/500
# 1/1 [==============================] - 0s 12ms/step - loss: 1.4188e-11
# Epoch 329/500
# 1/1 [==============================] - 0s 11ms/step - loss: 1.3097e-11
# Epoch 330/500
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1278e-11
# Epoch 331/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1278e-11
# Epoch 332/500
# 1/1 [==============================] - 0s 15ms/step - loss: 1.1005e-11
# Epoch 333/500
# 1/1 [==============================] - 0s 11ms/step - loss: 1.4279e-11
# Epoch 334/500
# 1/1 [==============================] - 0s 14ms/step - loss: 1.2460e-11
# Epoch 335/500
# 1/1 [==============================] - 0s 13ms/step - loss: 2.8103e-11
# Epoch 336/500
# 1/1 [==============================] - 0s 12ms/step - loss: 2.2283e-11
# Epoch 337/500
# 1/1 [==============================] - 0s 14ms/step - loss: 1.8281e-11
# Epoch 338/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.2369e-11
# Epoch 339/500
# 1/1 [==============================] - 0s 12ms/step - loss: 9.4587e-12
# Epoch 340/500
# 1/1 [==============================] - 0s 11ms/step - loss: 9.5497e-12
# Epoch 341/500
# 1/1 [==============================] - 0s 8ms/step - loss: 9.5497e-12
# Epoch 342/500
# 1/1 [==============================] - 0s 8ms/step - loss: 9.5497e-12
# Epoch 343/500
# 1/1 [==============================] - 0s 23ms/step - loss: 9.5497e-12
# Epoch 344/500
# 1/1 [==============================] - 0s 16ms/step - loss: 7.6398e-12
# Epoch 345/500
# 1/1 [==============================] - 0s 13ms/step - loss: 1.6371e-11
# Epoch 346/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.6371e-11
# Epoch 347/500
# 1/1 [==============================] - 0s 25ms/step - loss: 1.4552e-11
# Epoch 348/500
# 1/1 [==============================] - 0s 11ms/step - loss: 7.7307e-12
# Epoch 349/500
# 1/1 [==============================] - 0s 11ms/step - loss: 9.1859e-12
# Epoch 350/500
# 1/1 [==============================] - 0s 8ms/step - loss: 9.4587e-12
# Epoch 351/500
# 1/1 [==============================] - 0s 10ms/step - loss: 9.4587e-12
# Epoch 352/500
# 1/1 [==============================] - 0s 9ms/step - loss: 9.1859e-12
# Epoch 353/500
# 1/1 [==============================] - 0s 9ms/step - loss: 7.7307e-12
# Epoch 354/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.3551e-11
# Epoch 355/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.3551e-11
# Epoch 356/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.4552e-11
# Epoch 357/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.4552e-11
# Epoch 358/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.3551e-11
# Epoch 359/500
# 1/1 [==============================] - 0s 15ms/step - loss: 1.3551e-11
# Epoch 360/500
# 1/1 [==============================] - 0s 17ms/step - loss: 7.7307e-12
# Epoch 361/500
# 1/1 [==============================] - 0s 15ms/step - loss: 7.7307e-12
# Epoch 362/500
# 1/1 [==============================] - 0s 20ms/step - loss: 7.7307e-12
# Epoch 363/500
# 1/1 [==============================] - 0s 17ms/step - loss: 7.7307e-12
# Epoch 364/500
# 1/1 [==============================] - 0s 15ms/step - loss: 1.3551e-11
# Epoch 365/500
# 1/1 [==============================] - 0s 12ms/step - loss: 1.3551e-11
# Epoch 366/500
# 1/1 [==============================] - 0s 17ms/step - loss: 1.6098e-11
# Epoch 367/500
# 1/1 [==============================] - 0s 27ms/step - loss: 1.6007e-11
# Epoch 368/500
# 1/1 [==============================] - 0s 20ms/step - loss: 1.6098e-11
# Epoch 369/500
# 1/1 [==============================] - 0s 24ms/step - loss: 1.5007e-11
# Epoch 370/500
# 1/1 [==============================] - 0s 24ms/step - loss: 1.5007e-11
# Epoch 371/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.3551e-11
# Epoch 372/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.3551e-11
# Epoch 373/500
# 1/1 [==============================] - 0s 11ms/step - loss: 7.7307e-12
# Epoch 374/500
# 1/1 [==============================] - 0s 12ms/step - loss: 7.7307e-12
# Epoch 375/500
# 1/1 [==============================] - 0s 15ms/step - loss: 1.3551e-11
# Epoch 376/500
# 1/1 [==============================] - 0s 14ms/step - loss: 1.3551e-11
# Epoch 377/500
# 1/1 [==============================] - 0s 12ms/step - loss: 1.3551e-11
# Epoch 378/500
# 1/1 [==============================] - 0s 17ms/step - loss: 1.3551e-11
# Epoch 379/500
# 1/1 [==============================] - 0s 21ms/step - loss: 1.4643e-11
# Epoch 380/500
# 1/1 [==============================] - 0s 26ms/step - loss: 1.4552e-11
# Epoch 381/500
# 1/1 [==============================] - 0s 20ms/step - loss: 1.3551e-11
# Epoch 382/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.3551e-11
# Epoch 383/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.3551e-11
# Epoch 384/500
# 1/1 [==============================] - 0s 13ms/step - loss: 1.3551e-11
# Epoch 385/500
# 1/1 [==============================] - 0s 13ms/step - loss: 7.7307e-12
# Epoch 386/500
# 1/1 [==============================] - 0s 10ms/step - loss: 7.7307e-12
# Epoch 387/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.3551e-11
# Epoch 388/500
# 1/1 [==============================] - 0s 20ms/step - loss: 1.3551e-11
# Epoch 389/500
# 1/1 [==============================] - 0s 23ms/step - loss: 1.3551e-11
# Epoch 390/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3551e-11
# Epoch 391/500
# 1/1 [==============================] - 0s 17ms/step - loss: 1.4643e-11
# Epoch 392/500
# 1/1 [==============================] - 0s 12ms/step - loss: 1.4552e-11
# Epoch 393/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3551e-11
# Epoch 394/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.3551e-11
# Epoch 395/500
# 1/1 [==============================] - 0s 17ms/step - loss: 1.3551e-11
# Epoch 396/500
# 1/1 [==============================] - 0s 16ms/step - loss: 7.7307e-12
# Epoch 397/500
# 1/1 [==============================] - 0s 15ms/step - loss: 7.7307e-12
# Epoch 398/500
# 1/1 [==============================] - 0s 18ms/step - loss: 1.3551e-11
# Epoch 399/500
# 1/1 [==============================] - 0s 12ms/step - loss: 1.3551e-11
# Epoch 400/500
# 1/1 [==============================] - 0s 12ms/step - loss: 1.3551e-11
# Epoch 401/500
# 1/1 [==============================] - 0s 12ms/step - loss: 1.3551e-11
# Epoch 402/500
# 1/1 [==============================] - 0s 17ms/step - loss: 1.4643e-11
# Epoch 403/500
# 1/1 [==============================] - 0s 17ms/step - loss: 1.4552e-11
# Epoch 404/500
# 1/1 [==============================] - 0s 14ms/step - loss: 1.3551e-11
# Epoch 405/500
# 1/1 [==============================] - 0s 14ms/step - loss: 1.3551e-11
# Epoch 406/500
# 1/1 [==============================] - 0s 12ms/step - loss: 1.3551e-11
# Epoch 407/500
# 1/1 [==============================] - 0s 17ms/step - loss: 7.7307e-12
# Epoch 408/500
# 1/1 [==============================] - 0s 17ms/step - loss: 7.7307e-12
# Epoch 409/500
# 1/1 [==============================] - 0s 11ms/step - loss: 1.3551e-11
# Epoch 410/500
# 1/1 [==============================] - 0s 15ms/step - loss: 1.3551e-11
# Epoch 411/500
# 1/1 [==============================] - 0s 16ms/step - loss: 1.3551e-11
# Epoch 412/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.3551e-11
# Epoch 413/500
# 1/1 [==============================] - 0s 16ms/step - loss: 1.4643e-11
# Epoch 414/500
# 1/1 [==============================] - 0s 12ms/step - loss: 1.4552e-11
# Epoch 415/500
# 1/1 [==============================] - 0s 13ms/step - loss: 1.3551e-11
# Epoch 416/500
# 1/1 [==============================] - 0s 15ms/step - loss: 1.3551e-11
# Epoch 417/500
# 1/1 [==============================] - 0s 15ms/step - loss: 7.7307e-12
# Epoch 418/500
# 1/1 [==============================] - 0s 12ms/step - loss: 7.7307e-12
# Epoch 419/500
# 1/1 [==============================] - 0s 16ms/step - loss: 1.3551e-11
# Epoch 420/500
# 1/1 [==============================] - 0s 11ms/step - loss: 1.3551e-11
# Epoch 421/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.3551e-11
# Epoch 422/500
# 1/1 [==============================] - 0s 13ms/step - loss: 1.3551e-11
# Epoch 423/500
# 1/1 [==============================] - 0s 15ms/step - loss: 1.4643e-11
# Epoch 424/500
# 1/1 [==============================] - 0s 14ms/step - loss: 1.4643e-11
# Epoch 425/500
# 1/1 [==============================] - 0s 19ms/step - loss: 1.4643e-11
# Epoch 426/500
# 1/1 [==============================] - 0s 19ms/step - loss: 1.4643e-11
# Epoch 427/500
# 1/1 [==============================] - 0s 19ms/step - loss: 1.4643e-11
# Epoch 428/500
# 1/1 [==============================] - 0s 16ms/step - loss: 1.4643e-11
# Epoch 429/500
# 1/1 [==============================] - 0s 20ms/step - loss: 1.4643e-11
# Epoch 430/500
# 1/1 [==============================] - 0s 20ms/step - loss: 1.4643e-11
# Epoch 431/500
# 1/1 [==============================] - 0s 22ms/step - loss: 1.4643e-11
# Epoch 432/500
# 1/1 [==============================] - 0s 17ms/step - loss: 1.4643e-11
# Epoch 433/500
# 1/1 [==============================] - 0s 16ms/step - loss: 1.3551e-11
# Epoch 434/500
# 1/1 [==============================] - 0s 17ms/step - loss: 1.3551e-11
# Epoch 435/500
# 1/1 [==============================] - 0s 16ms/step - loss: 1.3551e-11
# Epoch 436/500
# 1/1 [==============================] - 0s 20ms/step - loss: 1.3551e-11
# Epoch 437/500
# 1/1 [==============================] - 0s 22ms/step - loss: 1.3551e-11
# Epoch 438/500
# 1/1 [==============================] - 0s 16ms/step - loss: 1.3551e-11
# Epoch 439/500
# 1/1 [==============================] - 0s 18ms/step - loss: 1.3551e-11
# Epoch 440/500
# 1/1 [==============================] - 0s 19ms/step - loss: 1.3551e-11
# Epoch 441/500
# 1/1 [==============================] - 0s 18ms/step - loss: 1.3551e-11
# Epoch 442/500
# 1/1 [==============================] - 0s 12ms/step - loss: 1.3551e-11
# Epoch 443/500
# 1/1 [==============================] - 0s 19ms/step - loss: 1.3551e-11
# Epoch 444/500
# 1/1 [==============================] - 0s 20ms/step - loss: 1.3461e-11
# Epoch 445/500
# 1/1 [==============================] - 0s 19ms/step - loss: 1.3461e-11
# Epoch 446/500
# 1/1 [==============================] - 0s 15ms/step - loss: 1.3461e-11
# Epoch 447/500
# 1/1 [==============================] - 0s 17ms/step - loss: 1.3461e-11
# Epoch 448/500
# 1/1 [==============================] - 0s 18ms/step - loss: 1.3461e-11
# Epoch 449/500
# 1/1 [==============================] - 0s 16ms/step - loss: 1.3461e-11
# Epoch 450/500
# 1/1 [==============================] - 0s 15ms/step - loss: 1.3461e-11
# Epoch 451/500
# 1/1 [==============================] - 0s 17ms/step - loss: 1.3461e-11
# Epoch 452/500
# 1/1 [==============================] - 0s 18ms/step - loss: 1.3461e-11
# Epoch 453/500
# 1/1 [==============================] - 0s 20ms/step - loss: 1.3461e-11
# Epoch 454/500
# 1/1 [==============================] - 0s 21ms/step - loss: 1.3461e-11
# Epoch 455/500
# 1/1 [==============================] - 0s 19ms/step - loss: 1.3461e-11
# Epoch 456/500
# 1/1 [==============================] - 0s 18ms/step - loss: 1.3461e-11
# Epoch 457/500
# 1/1 [==============================] - 0s 15ms/step - loss: 1.3461e-11
# Epoch 458/500
# 1/1 [==============================] - 0s 15ms/step - loss: 1.3461e-11
# Epoch 459/500
# 1/1 [==============================] - 0s 17ms/step - loss: 1.3461e-11
# Epoch 460/500
# 1/1 [==============================] - 0s 14ms/step - loss: 1.3461e-11
# Epoch 461/500
# 1/1 [==============================] - 0s 15ms/step - loss: 1.3461e-11
# Epoch 462/500
# 1/1 [==============================] - 0s 16ms/step - loss: 1.3461e-11
# Epoch 463/500
# 1/1 [==============================] - 0s 17ms/step - loss: 1.3461e-11
# Epoch 464/500
# 1/1 [==============================] - 0s 15ms/step - loss: 1.3461e-11
# Epoch 465/500
# 1/1 [==============================] - 0s 18ms/step - loss: 1.3461e-11
# Epoch 466/500
# 1/1 [==============================] - 0s 19ms/step - loss: 1.3461e-11
# Epoch 467/500
# 1/1 [==============================] - 0s 24ms/step - loss: 1.3461e-11
# Epoch 468/500
# 1/1 [==============================] - 0s 18ms/step - loss: 1.3461e-11
# Epoch 469/500
# 1/1 [==============================] - 0s 20ms/step - loss: 7.6398e-12
# Epoch 470/500
# 1/1 [==============================] - 0s 19ms/step - loss: 8.7311e-12
# Epoch 471/500
# 1/1 [==============================] - 0s 23ms/step - loss: 1.6462e-11
# Epoch 472/500
# 1/1 [==============================] - 0s 20ms/step - loss: 1.6826e-11
# Epoch 473/500
# 1/1 [==============================] - 0s 18ms/step - loss: 1.6462e-11
# Epoch 474/500
# 1/1 [==============================] - 0s 20ms/step - loss: 8.7311e-12
# Epoch 475/500
# 1/1 [==============================] - 0s 15ms/step - loss: 1.3461e-11
# Epoch 476/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.3461e-11
# Epoch 477/500
# 1/1 [==============================] - 0s 19ms/step - loss: 1.3461e-11
# Epoch 478/500
# 1/1 [==============================] - 0s 14ms/step - loss: 1.3461e-11
# Epoch 479/500
# 1/1 [==============================] - 0s 21ms/step - loss: 1.3461e-11
# Epoch 480/500
# 1/1 [==============================] - 0s 21ms/step - loss: 1.3461e-11
# Epoch 481/500
# 1/1 [==============================] - 0s 35ms/step - loss: 1.3461e-11
# Epoch 482/500
# 1/1 [==============================] - 0s 20ms/step - loss: 1.3461e-11
# Epoch 483/500
# 1/1 [==============================] - 0s 17ms/step - loss: 1.3461e-11
# Epoch 484/500
# 1/1 [==============================] - 0s 25ms/step - loss: 1.3461e-11
# Epoch 485/500
# 1/1 [==============================] - 0s 22ms/step - loss: 1.3461e-11
# Epoch 486/500
# 1/1 [==============================] - 0s 24ms/step - loss: 1.3461e-11
# Epoch 487/500
# 1/1 [==============================] - 0s 18ms/step - loss: 1.3461e-11
# Epoch 488/500
# 1/1 [==============================] - 0s 15ms/step - loss: 1.3461e-11
# Epoch 489/500
# 1/1 [==============================] - 0s 11ms/step - loss: 1.3461e-11
# Epoch 490/500
# 1/1 [==============================] - 0s 13ms/step - loss: 1.3461e-11
# Epoch 491/500
# 1/1 [==============================] - 0s 12ms/step - loss: 1.3461e-11
# Epoch 492/500
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3461e-11
# Epoch 493/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.3461e-11
# Epoch 494/500
# 1/1 [==============================] - 0s 12ms/step - loss: 1.3461e-11
# Epoch 495/500
# 1/1 [==============================] - 0s 13ms/step - loss: 1.3461e-11
# Epoch 496/500
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3461e-11
# Epoch 497/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.3461e-11
# Epoch 498/500
# 1/1 [==============================] - 0s 14ms/step - loss: 1.3461e-11
# Epoch 499/500
# 1/1 [==============================] - 0s 16ms/step - loss: 1.3461e-11
# Epoch 500/500
# 1/1 [==============================] - 0s 11ms/step - loss: 7.6398e-12
# Modelo entrenado!!

# %%
plt.xlabel('Epoch')
plt.ylabel('LossMagnitude')
plt.plot(m_history2.history['loss'])

# %%
prediction = model2.predict([100.0 ])

known_value = 212.0 #C2F(100.0)


print('Prediction = ', prediction)
print('Known value = ', known_value)
# Out:
# 1/1 [==============================] - 0s 71ms/step
# Prediction =  [[212.]]
# Known value =  212.0

# %%
print(hl1.get_weights())
print(hl2.get_weights())
print(outl.get_weights())
# Out:
# [array([[ 0.08707913, -0.02918679,  0.6674761 ]], dtype=float32), array([ 3.7078898, -0.9066184,  3.9514542], dtype=float32)]
# [array([[-1.1963867 ,  0.03495738, -0.5270225 ],
#        [-0.1190064 , -0.5931486 , -0.40717152],
#        [-0.39394745,  1.3449179 , -0.5570632 ]], dtype=float32), array([-3.7326846,  3.8664865, -3.4532323], dtype=float32)]
# [array([[-1.044663 ],
#        [ 1.0619159],
#        [-1.0970012]], dtype=float32), array([3.55325], dtype=float32)]

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---
#
# Here we have the function that gives the relation between tempereture in Celsius and Fahrenheit to create the input data.

# %%
def C2F(c_deg):
  return (9/5)*c_deg + 32

celsius = np.array([-40., -30., -10., -5., 0., 8., 15., 22., 38., 50.])
fahrenheit = C2F(celsius)
fahrenheit
# Out:
# array([-40. , -22. ,  14. ,  23. ,  32. ,  46.4,  59. ,  71.6, 100.4,
#        122. ])
