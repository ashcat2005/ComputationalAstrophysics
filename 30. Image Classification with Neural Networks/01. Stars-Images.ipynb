# %% [markdown]
# ![Astrofisica Computacional](../logo.PNG)

# %% [markdown]
# ---
# ## 01. Images
#
#
# Eduard Larrañaga (ealarranaga@unal.edu.co)
#
# ---

# %% [markdown]
# ### Abstract
#
# In this notebook we will implement a perceptron algorithm, which incorporates the idea of a linear regression and a activation function to define a classification method.
#
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt


def genImg():
    fuz = 0.5
    image_data = np.zeros([28,28])
    N = np.random.randint(6)
    for i in range(N):
        x,y = np.random.randint(28, size=2)
        image_data[x,y] = 1
        if x-1>=0:
            image_data[x-1,y] = np.random.rand()*fuz
            if y-1>=0:
                image_data[x-1,y-1] = np.random.rand()*fuz
                image_data[x,y-1] = np.random.rand()*fuz
            if y+1<28:
                image_data[x-1,y+1] = np.random.rand()*fuz
                image_data[x,y+1] = np.random.rand()*fuz
        if x+1<28:
            image_data[x+1,y] = np.random.rand()*fuz
            if y-1>=0:
                image_data[x+1,y-1] = np.random.rand()*fuz
            if y+1<28:
                image_data[x+1,y+1] = np.random.rand()*fuz
    return image_data, N

samples = 1000
data = np.zeros([samples,28,28])
targets = np.zeros(samples, dtype=int)


# Save training data
for j in range(samples):
    data[j], targets[j] = genImg()

np.save("star_image_train.npy", data)
np.save("star_label_train.npy", targets)


# Save test data
for j in range(samples):
    data[j], targets[j] = genImg()

np.save("star_image_test.npy", data)
np.save("star_label_test.npy", targets)

# %% [markdown]
# We can apply this perceptron to many samples to obtain the corresponding results,

# %%
datos = np.load("star_image_train.npy")
tar = np.load("star_label_train.npy")

for i in range(len(tar)//2):
    print(tar[i])
    plt.figure(figsize=(2,2))
    plt.imshow(datos[i], cmap='gray')
    plt.show()
# Out:
# 5
# 2
# 5
# 1
# 3
# 3
# 1
# 3
# 4
# 3
# 0
# 0
# 0
# 1
# 3
# 2
# 2
# 0
# 4
# 0
# 5
# 3
# 4
# 3
# 4
# 0
# 1
# 2
# 0
# 1
# 5
# 0
# 2
# 4
# 3
# 4
# 3
# 5
# 2
# 0
# 1
# 3
# 1
# 3
# 1
# 4
# 0
# 4
# 0
# 3
# 2
# 0
# 0
# 2
# 2
# 4
# 1
# 0
# 1
# 2
# 4
# 1
# 4
# 3
# 5
# 0
# 2
# 5
# 2
# 3
# 2
# 1
# 1
# 1
# 1
# 5
# 2
# 4
# 1
# 0
# 5
# 3
# 1
# 1
# 2
# 0
# 0
# 2
# 0
# 0
# 2
# 4
# 5
# 1
# 4
# 1
# 1
# 2
# 2
# 3
# 0
# 5
# 0
# 2
# 0
# 1
# 1
# 4
# 1
# 0
# 3
# 0
# 3
# 5
# 0
# 1
# 2
# 1
# 3
# 0
# 2
# 5
# 3
# 5
# 3
# 0
# 2
# 4
# 2
# 1
# 5
# 3
# 0
# 3
# 0
# 2
# 2
# 2
# 1
# 5
# 4
# 0
# 0
# 5
# 5
# 3
# 1
# 5
# 1
# 1
# 5
