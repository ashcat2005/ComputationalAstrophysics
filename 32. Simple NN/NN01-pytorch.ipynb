# %% [markdown]
# ![Astrofisica Computacional](../logo.PNG)

# %% [markdown]
# ---
# ## 01. First Neural Network with PyTorch
#
#
# Eduard Larrañaga (ealarranaga@unal.edu.co)
#
# ---

# %% [markdown]
# ### Abstract
#
# In this notebook we will implement a simple neural network to represent a linear model using `PyTorch`.
#
# ---

# %%
import torch
from torch import nn
import torch.optim as optim

import math
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation

torch.manual_seed(413)

# %% [markdown]
# ## The Dataset
#
# We will use a random dataset including 100 temperatures given in Celsius and Fahrenheit degrees.

# %%
def C2F(c_deg):
  return (9/5)*c_deg + 32

celsius = np.random.rand(100)*100-50
fahrenheit = C2F(celsius)

# %%
# It is possible to transform the numpy arrays into torch tensors with either
# of these commands. Note that the tensors are column vectors of
# the float32 type.

Ctensor = torch.tensor(celsius, dtype=torch.float32).reshape(-1,1)
Ftensor = torch.tensor(fahrenheit, dtype=torch.float32).reshape(-1,1)

Ctensor[:10], Ftensor[:10]
# Out:
# (tensor([[ 14.5214],
#          [ -7.6847],
#          [  0.7367],
#          [  3.8003],
#          [ 29.8717],
#          [ 30.1688],
#          [-45.7292],
#          [  4.1699],
#          [ -5.2632],
#          [-24.8107]]),
#  tensor([[ 58.1386],
#          [ 18.1675],
#          [ 33.3261],
#          [ 38.8405],
#          [ 85.7690],
#          [ 86.3039],
#          [-50.3126],
#          [ 39.5057],
#          [ 22.5262],
#          [-12.6592]]))

# %% [markdown]
# ---
#
# ## Building our first neural network
#
# There are many ways to define a model in PyTorch but, in all cases, we will define it as a function that takes an input and returns an output.
#
# The [Sequential](https://pytorch.org/docs/stable/generated/torch.nn.Sequential.html?highlight=sequential#torch.nn.Sequential) model will define the layers listed out. In this simple example, we will have a number of input features of just 1.
#
# As always, the other parameters for each layer or how many layers you need for a model is not an easy question. Often, the best neural network structure is found through a process of trial-and-error experimentation. Generally, you need a network large enough to capture the structure of the problem but small enough to make it fast.
#
# We will use dense layers (i.e. fully connected), wich are defined using the [Linear](https://pytorch.org/docs/stable/generated/torch.nn.Linear.html) class in PyTorch and the arguments are simply the in_features and the out_features.
#
# After each layer, we define the activation function. In this case we may use functions such as the [ReLU](https://pytorch.org/docs/stable/generated/torch.nn.ReLU.html?highlight=relu#torch.nn.ReLU) function or the [Sigmoid](https://pytorch.org/docs/stable/generated/torch.nn.Sigmoid.html?highlight=sigmoid#torch.nn.Sigmoid) function.

# %% [markdown]
# The first way to create the model is using the class [nn.Sequential()](https://pytorch.org/docs/stable/generated/torch.nn.Sequential.html?highlight=sequential#torch.nn.Sequential)

# %%
model = nn.Sequential(
    nn.Linear(1, 3),
    nn.ReLU(),
    nn.Linear(3, 3),
    nn.ReLU(),
    nn.Linear(3, 1),
    nn.Sigmoid()
)

print(model)
# Out:
# Sequential(
#   (0): Linear(in_features=1, out_features=3, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=3, out_features=3, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=3, out_features=1, bias=True)
#   (5): Sigmoid()
# )

# %% [markdown]
# The second way to define the model is as a Python class inherited from the [nn.Module()](https://pytorch.org/docs/stable/generated/torch.nn.Module.html?highlight=nn+module#torch.nn.Module).
#
# Note that it is needed to call the parent class’s constructor `super().__init__()` to bootstrap your model. It is also needed to define a `.forward()` method to specify how to produce the output tensor, once an input tensor x is provided.

# %%
class myNN(nn.Module):
  def __init__(self):
    super().__init__()
    self.model = nn.Sequential(nn.Linear(1, 3),
                               nn.ReLU(),
                               nn.Linear(3, 3),
                               nn.ReLU(),
                               nn.Linear(3, 1),
                               nn.Sigmoid())
  def forward(self, x):
    output = self.model(x)
    return output

model = myNN()
print(model)
# Out:
# myNN(
#   (model): Sequential(
#     (0): Linear(in_features=1, out_features=3, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=3, out_features=3, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=3, out_features=1, bias=True)
#     (5): Sigmoid()
#   )
# )

# %% [markdown]
# However, it is also possible to define each of the layers in the constructor independently. This may give a great freedom in the way that the output is obtained.

# %%
class myNN(nn.Module):
  def __init__(self):
    super().__init__()
    self.layer1 = nn.Linear(1, 3)
    self.act1 = nn.ReLU()
    self.layer2 = nn.Linear(3, 3)
    self.act2 = nn.ReLU()
    self.out_layer = nn.Linear(3, 1)
    self.out_act = nn.Sigmoid()

  def forward(self, x):
    x = self.act1(self.layer1(x))
    x = self.act2(self.layer2(x))
    output = self.out_act(self.out_layer(x))
    return output

model = myNN()
print(model)
# Out:
# myNN(
#   (layer1): Linear(in_features=1, out_features=3, bias=True)
#   (act1): ReLU()
#   (layer2): Linear(in_features=3, out_features=3, bias=True)
#   (act2): ReLU()
#   (out_layer): Linear(in_features=3, out_features=1, bias=True)
#   (out_act): Sigmoid()
# )

# %% [markdown]
# ---
# The next step is to define an 'optimizer' and a 'cost' or 'loss function'.
#
# ### The Optimizer
#
# We will use the [ADAM optimizer](https://pytorch.org/docs/stable/generated/torch.optim.Adam.html?highlight=adam#torch.optim.Adam) but PyTorch includes many more [optimizers](https://pytorch.org/docs/stable/optim.html).

# %%
optimizer = optim.Adam(model.parameters(), lr=0.01)

# %% [markdown]
# ### The Loss function
#
# The loss (or cost) is the function that measures the difference between predictions of the model and known targets. It is also the function that we want to minimize using the optimizer. We will use the [MSELoss](https://pytorch.org/docs/stable/generated/torch.nn.MSELoss.html?highlight=mse#torch.nn.MSELoss) function.
#
# PyTorch includes many more [loss functions](https://pytorch.org/docs/stable/generated/torch.nn.MSELoss.html?highlight=mse#torch.nn.MSELoss).
#
#
# ---
#
# #### The Mean-Squared-Error function
# In this example, we will use the [mean_squared_error](https://keras.io/api/losses/regression_losses/#mean_squared_error-function) loss function, which calculates the mean of the squared errors between targets and predictions.

# %%
loss_fn = nn.MSELoss()

# %% [markdown]
# ---
# ### Training a Model
#
# Once the model, the loss metric, and the optimizer are defined, it is time to train the algorithm.
#
# In order to train a neural network model, we need to define the number of epochs and the batches,
#
# **Epoch**: Number of times that the entire training dataset is passed to the model.
#
# **Batch**: Subset of samples passed to the model
#
# Hence, the dataset is split into batches and you pass the batches one by one into a model using a training loop. Once you have exhausted all the batches, you have finished one epoch. After that, you can start over again with the same dataset and start the second epoch, continuing to refine the model. The process is repeated until the output of the model is considered satisfactory.
#
# Usually, the size of a batch is limited by the system’s memory and the number of computation steps required is linearly proportional to the size of a batch.
#
# In PyTorch, it is possible to define a training loop (including two nested for-loops, one for epochs and one for batches).
#
# ---
#
# ## The Temperature Transformation Neural Network
#
# In our example, we will use the input data `'celsius'` y `'fahrenheit'` to train a linear neural network. Hence we will define 3 layers with no activation functions (i.e. we will use the identitiy function as the activation). Since this set has only 100 samples, we will use 1000 epochs to train the model with a batch of 16 samples.

# %%
Xtensor = Ctensor
ytensor = Ftensor

class myNN(nn.Module):
  def __init__(self):
    super().__init__()
    self.layer1 = nn.Linear(1, 3)
    self.act1 = nn.Identity()
    self.layer2 = nn.Linear(3, 3)
    self.act2 = nn.Identity()
    self.out_layer = nn.Linear(3, 1)
    self.out_act = nn.Identity()

  def forward(self, x):
    x = self.act1(self.layer1(x))
    x = self.act2(self.layer2(x))
    output = self.out_act(self.out_layer(x))
    return output

model = myNN()

optimizer = optim.Adam(model.parameters(), lr=0.001)
loss_fn = nn.MSELoss()

n_epochs = 1000
batch_size = 16
history = []
for epoch in range(n_epochs):
  for i in range(0,len(Xtensor), batch_size):
    Xbatch = Xtensor[i:i+batch_size]
    ybatch = ytensor[i:i+batch_size]
    y_pred = model(Xbatch)
    loss = loss_fn(y_pred, ybatch)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
  history.append(loss_fn(model(Xtensor), ytensor).detach().numpy())
  print(f'Finished epoch {epoch}, loss:{loss}')
# Out:
# Finished epoch 0, loss:4795.78125
# Finished epoch 1, loss:4744.12890625
# Finished epoch 2, loss:4695.685546875
# Finished epoch 3, loss:4649.58935546875
# Finished epoch 4, loss:4604.81884765625
# Finished epoch 5, loss:4560.14794921875
# Finished epoch 6, loss:4514.38916015625
# Finished epoch 7, loss:4466.68603515625
# Finished epoch 8, loss:4416.53466796875
# Finished epoch 9, loss:4363.6513671875
# Finished epoch 10, loss:4307.880859375
# Finished epoch 11, loss:4249.146484375
# Finished epoch 12, loss:4187.42578125
# Finished epoch 13, loss:4122.73828125
# Finished epoch 14, loss:4055.1318359375
# Finished epoch 15, loss:3984.678466796875
# Finished epoch 16, loss:3911.46337890625
# Finished epoch 17, loss:3835.580322265625
# Finished epoch 18, loss:3757.126220703125
# Finished epoch 19, loss:3676.1982421875
# Finished epoch 20, loss:3592.88623046875
# Finished epoch 21, loss:3507.276611328125
# Finished epoch 22, loss:3419.451904296875
# Finished epoch 23, loss:3329.48876953125
# Finished epoch 24, loss:3237.47265625
# Finished epoch 25, loss:3143.494140625
# Finished epoch 26, loss:3047.66552734375
# Finished epoch 27, loss:2950.124267578125
# Finished epoch 28, loss:2851.045654296875
# Finished epoch 29, loss:2750.64794921875
# Finished epoch 30, loss:2649.19677734375
# Finished epoch 31, loss:2547.01318359375
# Finished epoch 32, loss:2444.470703125
# Finished epoch 33, loss:2341.9970703125
# Finished epoch 34, loss:2240.06982421875
# Finished epoch 35, loss:2139.21435546875
# Finished epoch 36, loss:2039.99072265625
# Finished epoch 37, loss:1942.98779296875
# Finished epoch 38, loss:1848.806884765625
# Finished epoch 39, loss:1758.0458984375
# Finished epoch 40, loss:1671.28173828125
# Finished epoch 41, loss:1589.050048828125
# Finished epoch 42, loss:1511.8253173828125
# Finished epoch 43, loss:1440.001708984375
# Finished epoch 44, loss:1373.876220703125
# Finished epoch 45, loss:1313.63671875
# Finished epoch 46, loss:1259.349853515625
# Finished epoch 47, loss:1210.96337890625
# Finished epoch 48, loss:1168.306640625
# Finished epoch 49, loss:1131.10400390625
# Finished epoch 50, loss:1098.9893798828125
# Finished epoch 51, loss:1071.527099609375
# Finished epoch 52, loss:1048.235595703125
# Finished epoch 53, loss:1028.612060546875
# Finished epoch 54, loss:1012.1541748046875
# Finished epoch 55, loss:998.3797607421875
# Finished epoch 56, loss:986.841796875
# Finished epoch 57, loss:977.1387939453125
# Finished epoch 58, loss:968.9205322265625
# Finished epoch 59, loss:961.8885498046875
# Finished epoch 60, loss:955.7944946289062
# Finished epoch 61, loss:950.435791015625
# Finished epoch 62, loss:945.6503295898438
# Finished epoch 63, loss:941.3096923828125
# Finished epoch 64, loss:937.3139038085938
# Finished epoch 65, loss:933.5853881835938
# Finished epoch 66, loss:930.0648193359375
# Finished epoch 67, loss:926.70654296875
# Finished epoch 68, loss:923.4754028320312
# Finished epoch 69, loss:920.3450927734375
# Finished epoch 70, loss:917.295166015625
# Finished epoch 71, loss:914.3093872070312
# Finished epoch 72, loss:911.3761596679688
# Finished epoch 73, loss:908.4849853515625
# Finished epoch 74, loss:905.6293334960938
# Finished epoch 75, loss:902.8023681640625
# Finished epoch 76, loss:899.9995727539062
# Finished epoch 77, loss:897.217041015625
# Finished epoch 78, loss:894.4514770507812
# Finished epoch 79, loss:891.7005615234375
# Finished epoch 80, loss:888.9619140625
# Finished epoch 81, loss:886.233642578125
# Finished epoch 82, loss:883.5142211914062
# Finished epoch 83, loss:880.8024291992188
# Finished epoch 84, loss:878.0974731445312
# Finished epoch 85, loss:875.3976440429688
# Finished epoch 86, loss:872.7027587890625
# Finished epoch 87, loss:870.011962890625
# Finished epoch 88, loss:867.3240356445312
# Finished epoch 89, loss:864.6390380859375
# Finished epoch 90, loss:861.955810546875
# Finished epoch 91, loss:859.2744140625
# Finished epoch 92, loss:856.5943603515625
# Finished epoch 93, loss:853.9146728515625
# Finished epoch 94, loss:851.2354125976562
# Finished epoch 95, loss:848.5562133789062
# Finished epoch 96, loss:845.87646484375
# Finished epoch 97, loss:843.1961059570312
# Finished epoch 98, loss:840.5143432617188
# Finished epoch 99, loss:837.8310546875
# Finished epoch 100, loss:835.146484375
# Finished epoch 101, loss:832.4596557617188
# Finished epoch 102, loss:829.7706909179688
# Finished epoch 103, loss:827.0789184570312
# Finished epoch 104, loss:824.3843994140625
# Finished epoch 105, loss:821.6867065429688
# Finished epoch 106, loss:818.9855346679688
# Finished epoch 107, loss:816.2808837890625
# Finished epoch 108, loss:813.572265625
# Finished epoch 109, loss:810.8595581054688
# Finished epoch 110, loss:808.1426391601562
# Finished epoch 111, loss:805.420654296875
# Finished epoch 112, loss:802.6942749023438
# Finished epoch 113, loss:799.96240234375
# Finished epoch 114, loss:797.2257690429688
# Finished epoch 115, loss:794.4830322265625
# Finished epoch 116, loss:791.7350463867188
# Finished epoch 117, loss:788.9808349609375
# Finished epoch 118, loss:786.220458984375
# Finished epoch 119, loss:783.4536743164062
# Finished epoch 120, loss:780.680419921875
# Finished epoch 121, loss:777.9002685546875
# Finished epoch 122, loss:775.1129150390625
# Finished epoch 123, loss:772.3184814453125
# Finished epoch 124, loss:769.5164794921875
# Finished epoch 125, loss:766.7069091796875
# Finished epoch 126, loss:763.8895263671875
# Finished epoch 127, loss:761.0638427734375
# Finished epoch 128, loss:758.229736328125
# Finished epoch 129, loss:755.387451171875
# Finished epoch 130, loss:752.5364379882812
# Finished epoch 131, loss:749.6764526367188
# Finished epoch 132, loss:746.8071899414062
# Finished epoch 133, loss:743.9288330078125
# Finished epoch 134, loss:741.0410766601562
# Finished epoch 135, loss:738.1431884765625
# Finished epoch 136, loss:735.2356567382812
# Finished epoch 137, loss:732.31787109375
# Finished epoch 138, loss:729.39013671875
# Finished epoch 139, loss:726.4512939453125
# Finished epoch 140, loss:723.502197265625
# Finished epoch 141, loss:720.5421142578125
# Finished epoch 142, loss:717.570556640625
# Finished epoch 143, loss:714.5880737304688
# Finished epoch 144, loss:711.59375
# Finished epoch 145, loss:708.5878295898438
# Finished epoch 146, loss:705.5701904296875
# Finished epoch 147, loss:702.5401000976562
# Finished epoch 148, loss:699.4977416992188
# Finished epoch 149, loss:696.4430541992188
# Finished epoch 150, loss:693.3753662109375
# Finished epoch 151, loss:690.2947998046875
# Finished epoch 152, loss:687.201171875
# Finished epoch 153, loss:684.0942993164062
# Finished epoch 154, loss:680.9735717773438
# Finished epoch 155, loss:677.8394165039062
# Finished epoch 156, loss:674.6910400390625
# Finished epoch 157, loss:671.5288696289062
# Finished epoch 158, loss:668.3521728515625
# Finished epoch 159, loss:665.160888671875
# Finished epoch 160, loss:661.9549560546875
# Finished epoch 161, loss:658.7340698242188
# Finished epoch 162, loss:655.498046875
# Finished epoch 163, loss:652.2466430664062
# Finished epoch 164, loss:648.9796752929688
# Finished epoch 165, loss:645.6970825195312
# Finished epoch 166, loss:642.3986206054688
# Finished epoch 167, loss:639.083984375
# Finished epoch 168, loss:635.753173828125
# Finished epoch 169, loss:632.40576171875
# Finished epoch 170, loss:629.0415649414062
# Finished epoch 171, loss:625.660888671875
# Finished epoch 172, loss:622.2626953125
# Finished epoch 173, loss:618.84765625
# Finished epoch 174, loss:615.414794921875
# Finished epoch 175, loss:611.964599609375
# Finished epoch 176, loss:608.4965209960938
# Finished epoch 177, loss:605.0105590820312
# Finished epoch 178, loss:601.5064697265625
# Finished epoch 179, loss:597.9842529296875
# Finished epoch 180, loss:594.443359375
# Finished epoch 181, loss:590.884033203125
# Finished epoch 182, loss:587.3057250976562
# Finished epoch 183, loss:583.7085571289062
# Finished epoch 184, loss:580.0921630859375
# Finished epoch 185, loss:576.4567260742188
# Finished epoch 186, loss:572.8017578125
# Finished epoch 187, loss:569.1275024414062
# Finished epoch 188, loss:565.4332275390625
# Finished epoch 189, loss:561.719482421875
# Finished epoch 190, loss:557.9856567382812
# Finished epoch 191, loss:554.2318725585938
# Finished epoch 192, loss:550.4579467773438
# Finished epoch 193, loss:546.6637573242188
# Finished epoch 194, loss:542.8494873046875
# Finished epoch 195, loss:539.014404296875
# Finished epoch 196, loss:535.158935546875
# Finished epoch 197, loss:531.2830810546875
# Finished epoch 198, loss:527.3863525390625
# Finished epoch 199, loss:523.4688110351562
# Finished epoch 200, loss:519.5308837890625
# Finished epoch 201, loss:515.5718383789062
# Finished epoch 202, loss:511.59234619140625
# Finished epoch 203, loss:507.5915832519531
# Finished epoch 204, loss:503.5704040527344
# Finished epoch 205, loss:499.5281677246094
# Finished epoch 206, loss:495.46514892578125
# Finished epoch 207, loss:491.3812255859375
# Finished epoch 208, loss:487.2767333984375
# Finished epoch 209, loss:483.1514892578125
# Finished epoch 210, loss:479.0056457519531
# Finished epoch 211, loss:474.83905029296875
# Finished epoch 212, loss:470.6521301269531
# Finished epoch 213, loss:466.44512939453125
# Finished epoch 214, loss:462.2176818847656
# Finished epoch 215, loss:457.9703369140625
# Finished epoch 216, loss:453.7030944824219
# Finished epoch 217, loss:449.4161376953125
# Finished epoch 218, loss:445.1097106933594
# Finished epoch 219, loss:440.7840576171875
# Finished epoch 220, loss:436.4393615722656
# Finished epoch 221, loss:432.07586669921875
# Finished epoch 222, loss:427.6939697265625
# Finished epoch 223, loss:423.2939453125
# Finished epoch 224, loss:418.87591552734375
# Finished epoch 225, loss:414.44061279296875
# Finished epoch 226, loss:409.98809814453125
# Finished epoch 227, loss:405.51873779296875
# Finished epoch 228, loss:401.0330810546875
# Finished epoch 229, loss:396.5318603515625
# Finished epoch 230, loss:392.014892578125
# Finished epoch 231, loss:387.48333740234375
# Finished epoch 232, loss:382.93719482421875
# Finished epoch 233, loss:378.3771667480469
# Finished epoch 234, loss:373.80401611328125
# Finished epoch 235, loss:369.2182312011719
# Finished epoch 236, loss:364.62017822265625
# Finished epoch 237, loss:360.0111389160156
# Finished epoch 238, loss:355.3912658691406
# Finished epoch 239, loss:350.7613830566406
# Finished epoch 240, loss:346.1221618652344
# Finished epoch 241, loss:341.4748229980469
# Finished epoch 242, loss:336.81964111328125
# Finished epoch 243, loss:332.1576232910156
# Finished epoch 244, loss:327.48968505859375
# Finished epoch 245, loss:322.816650390625
# Finished epoch 246, loss:318.1396179199219
# Finished epoch 247, loss:313.4591064453125
# Finished epoch 248, loss:308.77642822265625
# Finished epoch 249, loss:304.0926208496094
# Finished epoch 250, loss:299.4085693359375
# Finished epoch 251, loss:294.72552490234375
# Finished epoch 252, loss:290.0442199707031
# Finished epoch 253, loss:285.3660888671875
# Finished epoch 254, loss:280.6921081542969
# Finished epoch 255, loss:276.0233154296875
# Finished epoch 256, loss:271.36114501953125
# Finished epoch 257, loss:266.7069091796875
# Finished epoch 258, loss:262.0616149902344
# Finished epoch 259, loss:257.42657470703125
# Finished epoch 260, loss:252.8030242919922
# Finished epoch 261, loss:248.19227600097656
# Finished epoch 262, loss:243.595703125
# Finished epoch 263, loss:239.01461791992188
# Finished epoch 264, loss:234.4501953125
# Finished epoch 265, loss:229.904052734375
# Finished epoch 266, loss:225.3775634765625
# Finished epoch 267, loss:220.87193298339844
# Finished epoch 268, loss:216.3885040283203
# Finished epoch 269, loss:211.92880249023438
# Finished epoch 270, loss:207.49440002441406
# Finished epoch 271, loss:203.08636474609375
# Finished epoch 272, loss:198.7063446044922
# Finished epoch 273, loss:194.3555908203125
# Finished epoch 274, loss:190.03564453125
# Finished epoch 275, loss:185.74778747558594
# Finished epoch 276, loss:181.49354553222656
# Finished epoch 277, loss:177.27407836914062
# Finished epoch 278, loss:173.09104919433594
# Finished epoch 279, loss:168.9456329345703
# Finished epoch 280, loss:164.83921813964844
# Finished epoch 281, loss:160.77310180664062
# Finished epoch 282, loss:156.7484893798828
# Finished epoch 283, loss:152.76687622070312
# Finished epoch 284, loss:148.8292694091797
# Finished epoch 285, loss:144.9371337890625
# Finished epoch 286, loss:141.0915069580078
# Finished epoch 287, loss:137.2935791015625
# Finished epoch 288, loss:133.54444885253906
# Finished epoch 289, loss:129.8453369140625
# Finished epoch 290, loss:126.19715881347656
# Finished epoch 291, loss:122.60086059570312
# Finished epoch 292, loss:119.05758666992188
# Finished epoch 293, loss:115.56815338134766
# Finished epoch 294, loss:112.13339233398438
# Finished epoch 295, loss:108.75418090820312
# Finished epoch 296, loss:105.43135070800781
# Finished epoch 297, loss:102.16548156738281
# Finished epoch 298, loss:98.95741271972656
# Finished epoch 299, loss:95.80766296386719
# Finished epoch 300, loss:92.71673583984375
# Finished epoch 301, loss:89.68524932861328
# Finished epoch 302, loss:86.71354675292969
# Finished epoch 303, loss:83.80211639404297
# Finished epoch 304, loss:80.95121765136719
# Finished epoch 305, loss:78.16107177734375
# Finished epoch 306, loss:75.43201446533203
# Finished epoch 307, loss:72.76409149169922
# Finished epoch 308, loss:70.15745544433594
# Finished epoch 309, loss:67.61203002929688
# Finished epoch 310, loss:65.12789916992188
# Finished epoch 311, loss:62.70491027832031
# Finished epoch 312, loss:60.3428955078125
# Finished epoch 313, loss:58.04176330566406
# Finished epoch 314, loss:55.80120849609375
# Finished epoch 315, loss:53.620849609375
# Finished epoch 316, loss:51.50041580200195
# Finished epoch 317, loss:49.43938446044922
# Finished epoch 318, loss:47.437286376953125
# Finished epoch 319, loss:45.493656158447266
# Finished epoch 320, loss:43.607872009277344
# Finished epoch 321, loss:41.77935028076172
# Finished epoch 322, loss:40.00743865966797
# Finished epoch 323, loss:38.29131317138672
# Finished epoch 324, loss:36.63037109375
# Finished epoch 325, loss:35.02372741699219
# Finished epoch 326, loss:33.47057342529297
# Finished epoch 327, loss:31.970029830932617
# Finished epoch 328, loss:30.521259307861328
# Finished epoch 329, loss:29.123323440551758
# Finished epoch 330, loss:27.77515411376953
# Finished epoch 331, loss:26.47591781616211
# Finished epoch 332, loss:25.22454071044922
# Finished epoch 333, loss:24.02008819580078
# Finished epoch 334, loss:22.861413955688477
# Finished epoch 335, loss:21.747495651245117
# Finished epoch 336, loss:20.677249908447266
# Finished epoch 337, loss:19.649717330932617
# Finished epoch 338, loss:18.663616180419922
# Finished epoch 339, loss:17.718013763427734
# Finished epoch 340, loss:16.811725616455078
# Finished epoch 341, loss:15.94363784790039
# Finished epoch 342, loss:15.112713813781738
# Finished epoch 343, loss:14.317855834960938
# Finished epoch 344, loss:13.557889938354492
# Finished epoch 345, loss:12.831769943237305
# Finished epoch 346, loss:12.138406753540039
# Finished epoch 347, loss:11.476730346679688
# Finished epoch 348, loss:10.845659255981445
# Finished epoch 349, loss:10.24416446685791
# Finished epoch 350, loss:9.671208381652832
# Finished epoch 351, loss:9.125703811645508
# Finished epoch 352, loss:8.606703758239746
# Finished epoch 353, loss:8.113182067871094
# Finished epoch 354, loss:7.644196510314941
# Finished epoch 355, loss:7.198776721954346
# Finished epoch 356, loss:6.775962829589844
# Finished epoch 357, loss:6.374906063079834
# Finished epoch 358, loss:5.9946370124816895
# Finished epoch 359, loss:5.634308815002441
# Finished epoch 360, loss:5.293092250823975
# Finished epoch 361, loss:4.970149993896484
# Finished epoch 362, loss:4.664663791656494
# Finished epoch 363, loss:4.375889301300049
# Finished epoch 364, loss:4.103030204772949
# Finished epoch 365, loss:3.845353126525879
# Finished epoch 366, loss:3.602173328399658
# Finished epoch 367, loss:3.3727879524230957
# Finished epoch 368, loss:3.156510591506958
# Finished epoch 369, loss:2.952741861343384
# Finished epoch 370, loss:2.7608556747436523
# Finished epoch 371, loss:2.58024525642395
# Finished epoch 372, loss:2.4103469848632812
# Finished epoch 373, loss:2.250610828399658
# Finished epoch 374, loss:2.100496292114258
# Finished epoch 375, loss:1.9595242738723755
# Finished epoch 376, loss:1.8271751403808594
# Finished epoch 377, loss:1.703017234802246
# Finished epoch 378, loss:1.5865843296051025
# Finished epoch 379, loss:1.4774531126022339
# Finished epoch 380, loss:1.3752104043960571
# Finished epoch 381, loss:1.2794941663742065
# Finished epoch 382, loss:1.1898967027664185
# Finished epoch 383, loss:1.1061019897460938
# Finished epoch 384, loss:1.0277698040008545
# Finished epoch 385, loss:0.9545660614967346
# Finished epoch 386, loss:0.8861976265907288
# Finished epoch 387, loss:0.8223654627799988
# Finished epoch 388, loss:0.7628079652786255
# Finished epoch 389, loss:0.7072633504867554
# Finished epoch 390, loss:0.6554827690124512
# Finished epoch 391, loss:0.6072420477867126
# Finished epoch 392, loss:0.562315821647644
# Finished epoch 393, loss:0.5204839706420898
# Finished epoch 394, loss:0.4815789759159088
# Finished epoch 395, loss:0.44538605213165283
# Finished epoch 396, loss:0.41174596548080444
# Finished epoch 397, loss:0.3804852366447449
# Finished epoch 398, loss:0.3514590561389923
# Finished epoch 399, loss:0.3245147466659546
# Finished epoch 400, loss:0.29950422048568726
# Finished epoch 401, loss:0.2763187885284424
# Finished epoch 402, loss:0.2548156678676605
# Finished epoch 403, loss:0.23489505052566528
# Finished epoch 404, loss:0.21643652021884918
# Finished epoch 405, loss:0.19935394823551178
# Finished epoch 406, loss:0.18354065716266632
# Finished epoch 407, loss:0.16891811788082123
# Finished epoch 408, loss:0.15539798140525818
# Finished epoch 409, loss:0.14289943873882294
# Finished epoch 410, loss:0.13135947287082672
# Finished epoch 411, loss:0.12070279568433762
# Finished epoch 412, loss:0.11086583882570267
# Finished epoch 413, loss:0.10178358852863312
# Finished epoch 414, loss:0.09341219812631607
# Finished epoch 415, loss:0.08569410443305969
# Finished epoch 416, loss:0.07858143001794815
# Finished epoch 417, loss:0.07203200459480286
# Finished epoch 418, loss:0.06600350141525269
# Finished epoch 419, loss:0.06045225262641907
# Finished epoch 420, loss:0.0553491935133934
# Finished epoch 421, loss:0.0506533682346344
# Finished epoch 422, loss:0.04634004831314087
# Finished epoch 423, loss:0.042375676333904266
# Finished epoch 424, loss:0.03873632103204727
# Finished epoch 425, loss:0.03539566695690155
# Finished epoch 426, loss:0.03232971951365471
# Finished epoch 427, loss:0.029517890885472298
# Finished epoch 428, loss:0.026940148323774338
# Finished epoch 429, loss:0.024578910320997238
# Finished epoch 430, loss:0.022413941100239754
# Finished epoch 431, loss:0.02043122984468937
# Finished epoch 432, loss:0.018616924062371254
# Finished epoch 433, loss:0.016957556828856468
# Finished epoch 434, loss:0.015439951792359352
# Finished epoch 435, loss:0.014052260667085648
# Finished epoch 436, loss:0.012783885933458805
# Finished epoch 437, loss:0.011625196784734726
# Finished epoch 438, loss:0.010567545890808105
# Finished epoch 439, loss:0.009602367877960205
# Finished epoch 440, loss:0.008721320889890194
# Finished epoch 441, loss:0.007918454706668854
# Finished epoch 442, loss:0.007186775095760822
# Finished epoch 443, loss:0.006519353482872248
# Finished epoch 444, loss:0.005911633372306824
# Finished epoch 445, loss:0.005358642432838678
# Finished epoch 446, loss:0.004855507984757423
# Finished epoch 447, loss:0.004398461431264877
# Finished epoch 448, loss:0.003981435671448708
# Finished epoch 449, loss:0.0036034579388797283
# Finished epoch 450, loss:0.003259585937485099
# Finished epoch 451, loss:0.002947781467810273
# Finished epoch 452, loss:0.0026642594020813704
# Finished epoch 453, loss:0.0024072066880762577
# Finished epoch 454, loss:0.00217392947524786
# Finished epoch 455, loss:0.0019626591820269823
# Finished epoch 456, loss:0.0017705910140648484
# Finished epoch 457, loss:0.0015972384717315435
# Finished epoch 458, loss:0.001440339139662683
# Finished epoch 459, loss:0.0012981044128537178
# Finished epoch 460, loss:0.001169408904388547
# Finished epoch 461, loss:0.0010528720449656248
# Finished epoch 462, loss:0.0009477590792812407
# Finished epoch 463, loss:0.0008525989833287895
# Finished epoch 464, loss:0.0007669167243875563
# Finished epoch 465, loss:0.0006895307451486588
# Finished epoch 466, loss:0.0006193238659761846
# Finished epoch 467, loss:0.0005565244355238974
# Finished epoch 468, loss:0.0004995436756871641
# Finished epoch 469, loss:0.0004483773373067379
# Finished epoch 470, loss:0.00040231901220977306
# Finished epoch 471, loss:0.0003605277743190527
# Finished epoch 472, loss:0.00032305449713021517
# Finished epoch 473, loss:0.00028950435807928443
# Finished epoch 474, loss:0.0002592852688394487
# Finished epoch 475, loss:0.00023205649631563574
# Finished epoch 476, loss:0.00020758180471602827
# Finished epoch 477, loss:0.00018560847092885524
# Finished epoch 478, loss:0.0001659066037973389
# Finished epoch 479, loss:0.00014816492330282927
# Finished epoch 480, loss:0.00013233389472588897
# Finished epoch 481, loss:0.00011814980098279193
# Finished epoch 482, loss:0.00010541665687924251
# Finished epoch 483, loss:9.408748155692592e-05
# Finished epoch 484, loss:8.379352948395535e-05
# Finished epoch 485, loss:7.463763904524967e-05
# Finished epoch 486, loss:6.645841494901106e-05
# Finished epoch 487, loss:5.919389514019713e-05
# Finished epoch 488, loss:5.2689629228552803e-05
# Finished epoch 489, loss:4.68462094431743e-05
# Finished epoch 490, loss:4.170211832388304e-05
# Finished epoch 491, loss:3.699353328556754e-05
# Finished epoch 492, loss:3.284490230726078e-05
# Finished epoch 493, loss:2.921127452282235e-05
# Finished epoch 494, loss:2.587802373454906e-05
# Finished epoch 495, loss:2.2983098460827023e-05
# Finished epoch 496, loss:2.0369870981085114e-05
# Finished epoch 497, loss:1.8031596482614987e-05
# Finished epoch 498, loss:1.597843220224604e-05
# Finished epoch 499, loss:1.415595761500299e-05
# Finished epoch 500, loss:1.2550161955005024e-05
# Finished epoch 501, loss:1.1100889423687477e-05
# Finished epoch 502, loss:9.7859538072953e-06
# Finished epoch 503, loss:8.66422942635836e-06
# Finished epoch 504, loss:7.674556400161237e-06
# Finished epoch 505, loss:6.763941200915724e-06
# Finished epoch 506, loss:5.9702615544665605e-06
# Finished epoch 507, loss:5.2369477998581715e-06
# Finished epoch 508, loss:4.595427526510321e-06
# Finished epoch 509, loss:4.07964125770377e-06
# Finished epoch 510, loss:3.5964931157650426e-06
# Finished epoch 511, loss:3.1572026273352094e-06
# Finished epoch 512, loss:2.791133738355711e-06
# Finished epoch 513, loss:2.4691089492989704e-06
# Finished epoch 514, loss:2.1539017325267196e-06
# Finished epoch 515, loss:1.884718585642986e-06
# Finished epoch 516, loss:1.6464127838844433e-06
# Finished epoch 517, loss:1.4388433555723168e-06
# Finished epoch 518, loss:1.2746613720082678e-06
# Finished epoch 519, loss:1.118501131713856e-06
# Finished epoch 520, loss:9.885770850814879e-07
# Finished epoch 521, loss:8.638380677439272e-07
# Finished epoch 522, loss:7.653707143617794e-07
# Finished epoch 523, loss:6.691197995678522e-07
# Finished epoch 524, loss:5.825131665915251e-07
# Finished epoch 525, loss:5.052661435911432e-07
# Finished epoch 526, loss:4.389012246974744e-07
# Finished epoch 527, loss:3.756040314328857e-07
# Finished epoch 528, loss:3.1998388294596225e-07
# Finished epoch 529, loss:2.7100486477138475e-07
# Finished epoch 530, loss:2.3443226382369176e-07
# Finished epoch 531, loss:1.993976184166968e-07
# Finished epoch 532, loss:1.6600461094640195e-07
# Finished epoch 533, loss:1.415655788150616e-07
# Finished epoch 534, loss:1.2586679076775908e-07
# Finished epoch 535, loss:1.1301835911581293e-07
# Finished epoch 536, loss:1.0305029718438163e-07
# Finished epoch 537, loss:9.414452506462112e-08
# Finished epoch 538, loss:8.634378900751472e-08
# Finished epoch 539, loss:7.999642548384145e-08
# Finished epoch 540, loss:7.446942618116736e-08
# Finished epoch 541, loss:6.934897101018578e-08
# Finished epoch 542, loss:6.414938980014995e-08
# Finished epoch 543, loss:5.9166268329136074e-08
# Finished epoch 544, loss:5.616402631858364e-08
# Finished epoch 545, loss:5.2827090257778764e-08
# Finished epoch 546, loss:5.023503035772592e-08
# Finished epoch 547, loss:4.729372449219227e-08
# Finished epoch 548, loss:4.5453816710505635e-08
# Finished epoch 549, loss:4.265621100785211e-08
# Finished epoch 550, loss:4.0695340430829674e-08
# Finished epoch 551, loss:3.828426997642964e-08
# Finished epoch 552, loss:3.622790245572105e-08
# Finished epoch 553, loss:3.5493030736688524e-08
# Finished epoch 554, loss:3.302648110548034e-08
# Finished epoch 555, loss:3.2496245694346726e-08
# Finished epoch 556, loss:3.180866769980639e-08
# Finished epoch 557, loss:3.096010914305225e-08
# Finished epoch 558, loss:3.164404915878549e-08
# Finished epoch 559, loss:3.096010914305225e-08
# Finished epoch 560, loss:3.047534846700728e-08
# Finished epoch 561, loss:3.0629053071606904e-08
# Finished epoch 562, loss:3.046261554118246e-08
# Finished epoch 563, loss:3.0294359021354467e-08
# Finished epoch 564, loss:2.9308466764632612e-08
# Finished epoch 565, loss:2.9308466764632612e-08
# Finished epoch 566, loss:2.979868440888822e-08
# Finished epoch 567, loss:2.964316081488505e-08
# Finished epoch 568, loss:2.8340764401946217e-08
# Finished epoch 569, loss:2.898468665080145e-08
# Finished epoch 570, loss:2.8494469006545842e-08
# Finished epoch 571, loss:2.8333488444332033e-08
# Finished epoch 572, loss:2.7857822715304792e-08
# Finished epoch 573, loss:2.7696842153090984e-08
# Finished epoch 574, loss:2.7387613954488188e-08
# Finished epoch 575, loss:2.6915586204268038e-08
# Finished epoch 576, loss:2.6926500140689313e-08
# Finished epoch 577, loss:2.753768058028072e-08
# Finished epoch 578, loss:2.6911948225460947e-08
# Finished epoch 579, loss:2.6597263058647513e-08
# Finished epoch 580, loss:2.6147063181269914e-08
# Finished epoch 581, loss:2.6604539016261697e-08
# Finished epoch 582, loss:2.645629137987271e-08
# Finished epoch 583, loss:2.552133082645014e-08
# Finished epoch 584, loss:2.5215740606654435e-08
# Finished epoch 585, loss:2.552133082645014e-08
# Finished epoch 586, loss:2.4619112082291394e-08
# Finished epoch 587, loss:2.4913788365665823e-08
# Finished epoch 588, loss:2.4769178708083928e-08
# Finished epoch 589, loss:2.4913788365665823e-08
# Finished epoch 590, loss:2.446904545649886e-08
# Finished epoch 591, loss:2.4320797820109874e-08
# Finished epoch 592, loss:2.3724169295746833e-08
# Finished epoch 593, loss:2.3290340323001146e-08
# Finished epoch 594, loss:2.3585016606375575e-08
# Finished epoch 595, loss:2.32885213335976e-08
# Finished epoch 596, loss:2.3010215954855084e-08
# Finished epoch 597, loss:2.2995664039626718e-08
# Finished epoch 598, loss:2.2706444724462926e-08
# Finished epoch 599, loss:2.2155290935188532e-08
# Finished epoch 600, loss:2.2563654056284577e-08
# Finished epoch 601, loss:2.2283529688138515e-08
# Finished epoch 602, loss:2.2283529688138515e-08
# Finished epoch 603, loss:2.1159394236747175e-08
# Finished epoch 604, loss:2.1573214326053858e-08
# Finished epoch 605, loss:2.0752850105054677e-08
# Finished epoch 606, loss:2.0337211026344448e-08
# Finished epoch 607, loss:2.158049028366804e-08
# Finished epoch 608, loss:2.0201696315780282e-08
# Finished epoch 609, loss:2.0740117179229856e-08
# Finished epoch 610, loss:2.0602783479262143e-08
# Finished epoch 611, loss:2.006436261581257e-08
# Finished epoch 612, loss:1.966327545233071e-08
# Finished epoch 613, loss:1.913213054649532e-08
# Finished epoch 614, loss:1.9661456462927163e-08
# Finished epoch 615, loss:1.9124854588881135e-08
# Finished epoch 616, loss:1.940315996762365e-08
# Finished epoch 617, loss:1.8864739104174078e-08
# Finished epoch 618, loss:1.8600985640659928e-08
# Finished epoch 619, loss:1.8481841834727675e-08
# Finished epoch 620, loss:1.83499651029706e-08
# Finished epoch 621, loss:1.8351784092374146e-08
# Finished epoch 622, loss:1.7976162780541927e-08
# Finished epoch 623, loss:1.8089849618263543e-08
# Finished epoch 624, loss:1.7833372112363577e-08
# Finished epoch 625, loss:1.6827470972202718e-08
# Finished epoch 626, loss:1.71976353158243e-08
# Finished epoch 627, loss:1.6953890735749155e-08
# Finished epoch 628, loss:1.6829289961606264e-08
# Finished epoch 629, loss:1.6702870198059827e-08
# Finished epoch 630, loss:1.682201400399208e-08
# Finished epoch 631, loss:1.5975274436641484e-08
# Finished epoch 632, loss:1.6332705854438245e-08
# Finished epoch 633, loss:1.6332705854438245e-08
# Finished epoch 634, loss:1.6090780263766646e-08
# Finished epoch 635, loss:1.5854311641305685e-08
# Finished epoch 636, loss:1.537409843876958e-08
# Finished epoch 637, loss:1.5254954632837325e-08
# Finished epoch 638, loss:1.4906618162058294e-08
# Finished epoch 639, loss:1.4671968529000878e-08
# Finished epoch 640, loss:1.4671968529000878e-08
# Finished epoch 641, loss:1.4450051821768284e-08
# Finished epoch 642, loss:1.4673787518404424e-08
# Finished epoch 643, loss:1.4220859156921506e-08
# Finished epoch 644, loss:1.421904016751796e-08
# Finished epoch 645, loss:1.4327270037028939e-08
# Finished epoch 646, loss:1.3764292816631496e-08
# Finished epoch 647, loss:1.3428689271677285e-08
# Finished epoch 648, loss:1.3428689271677285e-08
# Finished epoch 649, loss:1.3214048522058874e-08
# Finished epoch 650, loss:1.2882082955911756e-08
# Finished epoch 651, loss:1.3316821423359215e-08
# Finished epoch 652, loss:1.2461896403692663e-08
# Finished epoch 653, loss:1.3210410543251783e-08
# Finished epoch 654, loss:1.256648829439655e-08
# Finished epoch 655, loss:1.2773853086400777e-08
# Finished epoch 656, loss:1.2245436664670706e-08
# Finished epoch 657, loss:1.2458258424885571e-08
# Finished epoch 658, loss:1.2140844773966819e-08
# Finished epoch 659, loss:1.1823431123048067e-08
# Finished epoch 660, loss:1.171883923234418e-08
# Finished epoch 661, loss:1.171883923234418e-08
# Finished epoch 662, loss:1.1210431694053113e-08
# Finished epoch 663, loss:1.0918483894784003e-08
# Finished epoch 664, loss:1.1208612704649568e-08
# Finished epoch 665, loss:1.133685145759955e-08
# Finished epoch 666, loss:1.0813892004080117e-08
# Finished epoch 667, loss:1.0521944204811007e-08
# Finished epoch 668, loss:1.0813892004080117e-08
# Finished epoch 669, loss:1.023727236315608e-08
# Finished epoch 670, loss:1.041735231410712e-08
# Finished epoch 671, loss:1.0139956430066377e-08
# Finished epoch 672, loss:1.0321855370420963e-08
# Finished epoch 673, loss:1.0325493349228054e-08
# Finished epoch 674, loss:9.844370651990175e-09
# Finished epoch 675, loss:9.747054718900472e-09
# Finished epoch 676, loss:9.747054718900472e-09
# Finished epoch 677, loss:9.464201866649091e-09
# Finished epoch 678, loss:9.466020856052637e-09
# Finished epoch 679, loss:9.285940905101597e-09
# Finished epoch 680, loss:8.923962013795972e-09
# Finished epoch 681, loss:9.194081940222532e-09
# Finished epoch 682, loss:8.83028405951336e-09
# Finished epoch 683, loss:9.102222975343466e-09
# Finished epoch 684, loss:8.923962013795972e-09
# Finished epoch 685, loss:8.648385119158775e-09
# Finished epoch 686, loss:8.558345143683255e-09
# Finished epoch 687, loss:7.964445103425533e-09
# Finished epoch 688, loss:7.964445103425533e-09
# Finished epoch 689, loss:7.78982212068513e-09
# Finished epoch 690, loss:7.78982212068513e-09
# Finished epoch 691, loss:7.626113074366003e-09
# Finished epoch 692, loss:7.712515071034431e-09
# Finished epoch 693, loss:7.3705450631678104e-09
# Finished epoch 694, loss:7.3705450631678104e-09
# Finished epoch 695, loss:7.287781045306474e-09
# Finished epoch 696, loss:7.214111974462867e-09
# Finished epoch 697, loss:7.13134795660153e-09
# Finished epoch 698, loss:6.967638910282403e-09
# Finished epoch 699, loss:6.886693881824613e-09
# Finished epoch 700, loss:6.886693881824613e-09
# Finished epoch 701, loss:6.967638910282403e-09
# Finished epoch 702, loss:6.501977622974664e-09
# Finished epoch 703, loss:6.352820491883904e-09
# Finished epoch 704, loss:6.273694452829659e-09
# Finished epoch 705, loss:6.19638740317896e-09
# Finished epoch 706, loss:6.054506229702383e-09
# Finished epoch 707, loss:5.70253178011626e-09
# Finished epoch 708, loss:5.840774974785745e-09
# Finished epoch 709, loss:6.043592293281108e-09
# Finished epoch 710, loss:6.349182513076812e-09
# Finished epoch 711, loss:5.490619514603168e-09
# Finished epoch 712, loss:5.828042048960924e-09
# Finished epoch 713, loss:5.752553988713771e-09
# Finished epoch 714, loss:5.535184754990041e-09
# Finished epoch 715, loss:5.678884917870164e-09
# Finished epoch 716, loss:5.678884917870164e-09
# Finished epoch 717, loss:5.258698365651071e-09
# Finished epoch 718, loss:5.330548447091132e-09
# Finished epoch 719, loss:5.054062057752162e-09
# Finished epoch 720, loss:5.465153662953526e-09
# Finished epoch 721, loss:5.054062057752162e-09
# Finished epoch 722, loss:4.788489604834467e-09
# Finished epoch 723, loss:4.8476067604497075e-09
# Finished epoch 724, loss:4.781213647220284e-09
# Finished epoch 725, loss:4.653884388972074e-09
# Finished epoch 726, loss:4.722096491605043e-09
# Finished epoch 727, loss:4.58749127574265e-09
# Finished epoch 728, loss:4.653884388972074e-09
# Finished epoch 729, loss:4.472894943319261e-09
# Finished epoch 730, loss:4.275534593034536e-09
# Finished epoch 731, loss:4.275534593034536e-09
# Finished epoch 732, loss:4.090907168574631e-09
# Finished epoch 733, loss:4.090907168574631e-09
# Finished epoch 734, loss:4.028152034152299e-09
# Finished epoch 735, loss:4.148205334786326e-09
# Finished epoch 736, loss:3.904460754711181e-09
# Finished epoch 737, loss:3.843524609692395e-09
# Finished epoch 738, loss:3.843524609692395e-09
# Finished epoch 739, loss:4.028152034152299e-09
# Finished epoch 740, loss:3.908098733518273e-09
# Finished epoch 741, loss:3.6716301110573113e-09
# Finished epoch 742, loss:3.845343599095941e-09
# Finished epoch 743, loss:3.5661287256516516e-09
# Finished epoch 744, loss:3.784407454077154e-09
# Finished epoch 745, loss:3.788045432884246e-09
# Finished epoch 746, loss:3.614331944845617e-09
# Finished epoch 747, loss:3.72710928786546e-09
# Finished epoch 748, loss:3.5697667044587433e-09
# Finished epoch 749, loss:3.788045432884246e-09
# Finished epoch 750, loss:3.6197889130562544e-09
# Finished epoch 751, loss:3.5552147892303765e-09
# Finished epoch 752, loss:3.281456883996725e-09
# Finished epoch 753, loss:3.499735612422228e-09
# Finished epoch 754, loss:3.1222953111864626e-09
# Finished epoch 755, loss:3.1222953111864626e-09
# Finished epoch 756, loss:3.064997144974768e-09
# Finished epoch 757, loss:3.118657332379371e-09
# Finished epoch 758, loss:3.118657332379371e-09
# Finished epoch 759, loss:3.064997144974768e-09
# Finished epoch 760, loss:3.0095179681666195e-09
# Finished epoch 761, loss:3.064997144974768e-09
# Finished epoch 762, loss:2.9558577807620168e-09
# Finished epoch 763, loss:3.0095179681666195e-09
# Finished epoch 764, loss:2.8594513423740864e-09
# Finished epoch 765, loss:2.7539499569684267e-09
# Finished epoch 766, loss:2.8057911549694836e-09
# Finished epoch 767, loss:2.7557689463719726e-09
# Finished epoch 768, loss:2.7557689463719726e-09
# Finished epoch 769, loss:2.8057911549694836e-09
# Finished epoch 770, loss:2.6557245291769505e-09
# Finished epoch 771, loss:2.7557689463719726e-09
# Finished epoch 772, loss:2.6539055397734046e-09
# Finished epoch 773, loss:2.7039277483709157e-09
# Finished epoch 774, loss:2.5665940484032035e-09
# Finished epoch 775, loss:2.6557245291769505e-09
# Finished epoch 776, loss:2.5147528504021466e-09
# Finished epoch 777, loss:2.5147528504021466e-09
# Finished epoch 778, loss:2.5183908292092383e-09
# Finished epoch 779, loss:2.370143192820251e-09
# Finished epoch 780, loss:2.230990503448993e-09
# Finished epoch 781, loss:2.4665496312081814e-09
# Finished epoch 782, loss:2.3219399736262858e-09
# Finished epoch 783, loss:2.2773747332394123e-09
# Finished epoch 784, loss:2.3255779524333775e-09
# Finished epoch 785, loss:2.10275175049901e-09
# Finished epoch 786, loss:2.1473169908858836e-09
# Finished epoch 787, loss:2.1864252630621195e-09
# Finished epoch 788, loss:2.1400410332717e-09
# Finished epoch 789, loss:2.0972947822883725e-09
# Finished epoch 790, loss:2.1400410332717e-09
# Finished epoch 791, loss:2.0563675207085907e-09
# Finished epoch 792, loss:2.013621269725263e-09
# Finished epoch 793, loss:1.8198988982476294e-09
# Finished epoch 794, loss:1.7680577002465725e-09
# Finished epoch 795, loss:1.6916601452976465e-09
# Finished epoch 796, loss:1.6489138943143189e-09
# Finished epoch 797, loss:1.8089849618263543e-09
# Finished epoch 798, loss:1.6898411558941007e-09
# Finished epoch 799, loss:1.6898411558941007e-09
# Finished epoch 800, loss:1.8089849618263543e-09
# Finished epoch 801, loss:1.8517312128096819e-09
# Finished epoch 802, loss:1.8517312128096819e-09
# Finished epoch 803, loss:1.8517312128096819e-09
# Finished epoch 804, loss:1.812622940633446e-09
# Finished epoch 805, loss:1.6489138943143189e-09
# Finished epoch 806, loss:1.609805622138083e-09
# Finished epoch 807, loss:1.609805622138083e-09
# Finished epoch 808, loss:1.609805622138083e-09
# Finished epoch 809, loss:1.5315890777856112e-09
# Finished epoch 810, loss:1.457010512240231e-09
# Finished epoch 811, loss:1.4924808056093752e-09
# Finished epoch 812, loss:1.4624674804508686e-09
# Finished epoch 813, loss:1.5315890777856112e-09
# Finished epoch 814, loss:1.5688783605583012e-09
# Finished epoch 815, loss:1.457010512240231e-09
# Finished epoch 816, loss:1.3260432751849294e-09
# Finished epoch 817, loss:1.3878889149054885e-09
# Finished epoch 818, loss:1.3878889149054885e-09
# Finished epoch 819, loss:1.1577867553569376e-09
# Finished epoch 820, loss:1.2851160136051476e-09
# Finished epoch 821, loss:1.0568328434601426e-09
# Finished epoch 822, loss:1.088665158022195e-09
# Finished epoch 823, loss:1.088665158022195e-09
# Finished epoch 824, loss:1.1241354513913393e-09
# Finished epoch 825, loss:1.1241354513913393e-09
# Finished epoch 826, loss:1.088665158022195e-09
# Finished epoch 827, loss:1.0568328434601426e-09
# Finished epoch 828, loss:1.0568328434601426e-09
# Finished epoch 829, loss:1.0695657692849636e-09
# Finished epoch 830, loss:1.0077201295644045e-09
# Finished epoch 831, loss:1.053194864653051e-09
# Finished epoch 832, loss:9.686118573881686e-10
# Finished epoch 833, loss:8.703864295966923e-10
# Finished epoch 834, loss:9.38598532229662e-10
# Finished epoch 835, loss:8.703864295966923e-10
# Finished epoch 836, loss:8.36735125631094e-10
# Finished epoch 837, loss:8.785718819126487e-10
# Finished epoch 838, loss:9.067662176676095e-10
# Finished epoch 839, loss:9.067662176676095e-10
# Finished epoch 840, loss:8.785718819126487e-10
# Finished epoch 841, loss:9.38598532229662e-10
# Finished epoch 842, loss:8.085407898761332e-10
# Finished epoch 843, loss:7.767084753140807e-10
# Finished epoch 844, loss:9.067662176676095e-10
# Finished epoch 845, loss:8.48558556754142e-10
# Finished epoch 846, loss:7.466951501555741e-10
# Finished epoch 847, loss:8.521965355612338e-10
# Finished epoch 848, loss:6.921254680491984e-10
# Finished epoch 849, loss:7.203198038041592e-10
# Finished epoch 850, loss:6.921254680491984e-10
# Finished epoch 851, loss:7.203198038041592e-10
# Finished epoch 852, loss:7.466951501555741e-10
# Finished epoch 853, loss:8.012648322619498e-10
# Finished epoch 854, loss:7.466951501555741e-10
# Finished epoch 855, loss:7.466951501555741e-10
# Finished epoch 856, loss:7.748894859105349e-10
# Finished epoch 857, loss:6.921254680491984e-10
# Finished epoch 858, loss:7.466951501555741e-10
# Finished epoch 859, loss:7.203198038041592e-10
# Finished epoch 860, loss:6.448317435570061e-10
# Finished epoch 861, loss:6.994014256633818e-10
# Finished epoch 862, loss:6.71207089908421e-10
# Finished epoch 863, loss:7.748894859105349e-10
# Finished epoch 864, loss:6.484697223640978e-10
# Finished epoch 865, loss:6.675691111013293e-10
# Finished epoch 866, loss:6.411937647499144e-10
# Finished epoch 867, loss:6.657501216977835e-10
# Finished epoch 868, loss:6.921254680491984e-10
# Finished epoch 869, loss:6.448317435570061e-10
# Finished epoch 870, loss:6.448317435570061e-10
# Finished epoch 871, loss:6.202753866091371e-10
# Finished epoch 872, loss:5.939000402577221e-10
# Finished epoch 873, loss:5.939000402577221e-10
# Finished epoch 874, loss:5.939000402577221e-10
# Finished epoch 875, loss:6.184563972055912e-10
# Finished epoch 876, loss:6.184563972055912e-10
# Finished epoch 877, loss:6.448317435570061e-10
# Finished epoch 878, loss:6.202753866091371e-10
# Finished epoch 879, loss:6.202753866091371e-10
# Finished epoch 880, loss:6.202753866091371e-10
# Finished epoch 881, loss:5.939000402577221e-10
# Finished epoch 882, loss:6.448317435570061e-10
# Finished epoch 883, loss:6.202753866091371e-10
# Finished epoch 884, loss:6.448317435570061e-10
# Finished epoch 885, loss:6.448317435570061e-10
# Finished epoch 886, loss:5.939000402577221e-10
# Finished epoch 887, loss:5.939000402577221e-10
# Finished epoch 888, loss:6.202753866091371e-10
# Finished epoch 889, loss:6.411937647499144e-10
# Finished epoch 890, loss:6.675691111013293e-10
# Finished epoch 891, loss:6.921254680491984e-10
# Finished epoch 892, loss:5.720721674151719e-10
# Finished epoch 893, loss:5.475158104673028e-10
# Finished epoch 894, loss:6.202753866091371e-10
# Finished epoch 895, loss:5.07498043589294e-10
# Finished epoch 896, loss:6.202753866091371e-10
# Finished epoch 897, loss:7.22138793207705e-10
# Finished epoch 898, loss:6.048139766789973e-10
# Finished epoch 899, loss:5.293259164318442e-10
# Finished epoch 900, loss:5.293259164318442e-10
# Finished epoch 901, loss:5.784386303275824e-10
# Finished epoch 902, loss:5.06588548887521e-10
# Finished epoch 903, loss:5.311449058353901e-10
# Finished epoch 904, loss:5.311449058353901e-10
# Finished epoch 905, loss:5.466063157655299e-10
# Finished epoch 906, loss:5.466063157655299e-10
# Finished epoch 907, loss:5.711626727133989e-10
# Finished epoch 908, loss:5.538822733797133e-10
# Finished epoch 909, loss:5.939000402577221e-10
# Finished epoch 910, loss:5.238689482212067e-10
# Finished epoch 911, loss:5.711626727133989e-10
# Finished epoch 912, loss:5.06588548887521e-10
# Finished epoch 913, loss:5.06588548887521e-10
# Finished epoch 914, loss:6.08451955486089e-10
# Finished epoch 915, loss:4.81122697237879e-10
# Finished epoch 916, loss:4.1109160520136356e-10
# Finished epoch 917, loss:6.08451955486089e-10
# Finished epoch 918, loss:5.06588548887521e-10
# Finished epoch 919, loss:5.06588548887521e-10
# Finished epoch 920, loss:5.06588548887521e-10
# Finished epoch 921, loss:5.647962098009884e-10
# Finished epoch 922, loss:4.5838532969355583e-10
# Finished epoch 923, loss:4.838511813431978e-10
# Finished epoch 924, loss:4.838511813431978e-10
# Finished epoch 925, loss:4.838511813431978e-10
# Finished epoch 926, loss:4.856701707467437e-10
# Finished epoch 927, loss:4.6293280320242047e-10
# Finished epoch 928, loss:4.856701707467437e-10
# Finished epoch 929, loss:5.06588548887521e-10
# Finished epoch 930, loss:4.838511813431978e-10
# Finished epoch 931, loss:4.6293280320242047e-10
# Finished epoch 932, loss:4.43833414465189e-10
# Finished epoch 933, loss:4.856701707467437e-10
# Finished epoch 934, loss:4.5292836148291826e-10
# Finished epoch 935, loss:4.82032191939652e-10
# Finished epoch 936, loss:5.029505700804293e-10
# Finished epoch 937, loss:4.5292836148291826e-10
# Finished epoch 938, loss:4.1109160520136356e-10
# Finished epoch 939, loss:4.1109160520136356e-10
# Finished epoch 940, loss:4.5292836148291826e-10
# Finished epoch 941, loss:4.420144250616431e-10
# Finished epoch 942, loss:5.029505700804293e-10
# Finished epoch 943, loss:4.838511813431978e-10
# Finished epoch 944, loss:4.43833414465189e-10
# Finished epoch 945, loss:4.43833414465189e-10
# Finished epoch 946, loss:4.43833414465189e-10
# Finished epoch 947, loss:4.6293280320242047e-10
# Finished epoch 948, loss:4.6293280320242047e-10
# Finished epoch 949, loss:4.6293280320242047e-10
# Finished epoch 950, loss:4.43833414465189e-10
# Finished epoch 951, loss:4.43833414465189e-10
# Finished epoch 952, loss:3.9381120586767793e-10
# Finished epoch 953, loss:4.2291503632441163e-10
# Finished epoch 954, loss:3.383320290595293e-10
# Finished epoch 955, loss:3.383320290595293e-10
# Finished epoch 956, loss:3.3651303965598345e-10
# Finished epoch 957, loss:3.3651303965598345e-10
# Finished epoch 958, loss:4.1109160520136356e-10
# Finished epoch 959, loss:4.2291503632441163e-10
# Finished epoch 960, loss:4.43833414465189e-10
# Finished epoch 961, loss:4.05634636990726e-10
# Finished epoch 962, loss:4.43833414465189e-10
# Finished epoch 963, loss:4.1109160520136356e-10
# Finished epoch 964, loss:4.05634636990726e-10
# Finished epoch 965, loss:4.43833414465189e-10
# Finished epoch 966, loss:4.05634636990726e-10
# Finished epoch 967, loss:4.2655301513150334e-10
# Finished epoch 968, loss:4.05634636990726e-10
# Finished epoch 969, loss:3.3287506084889174e-10
# Finished epoch 970, loss:3.3287506084889174e-10
# Finished epoch 971, loss:3.710738383233547e-10
# Finished epoch 972, loss:3.3287506084889174e-10
# Finished epoch 973, loss:3.710738383233547e-10
# Finished epoch 974, loss:3.710738383233547e-10
# Finished epoch 975, loss:3.3287506084889174e-10
# Finished epoch 976, loss:4.05634636990726e-10
# Finished epoch 977, loss:4.2655301513150334e-10
# Finished epoch 978, loss:4.05634636990726e-10
# Finished epoch 979, loss:4.2655301513150334e-10
# Finished epoch 980, loss:4.2655301513150334e-10
# Finished epoch 981, loss:3.901732270605862e-10
# Finished epoch 982, loss:3.901732270605862e-10
# Finished epoch 983, loss:4.05634636990726e-10
# Finished epoch 984, loss:3.001332515850663e-10
# Finished epoch 985, loss:3.001332515850663e-10
# Finished epoch 986, loss:3.001332515850663e-10
# Finished epoch 987, loss:3.001332515850663e-10
# Finished epoch 988, loss:3.001332515850663e-10
# Finished epoch 989, loss:3.001332515850663e-10
# Finished epoch 990, loss:3.001332515850663e-10
# Finished epoch 991, loss:3.001332515850663e-10
# Finished epoch 992, loss:3.2105162972584367e-10
# Finished epoch 993, loss:3.9381120586767793e-10
# Finished epoch 994, loss:3.474269760772586e-10
# Finished epoch 995, loss:3.728928277269006e-10
# Finished epoch 996, loss:3.728928277269006e-10
# Finished epoch 997, loss:3.6834535421803594e-10
# Finished epoch 998, loss:2.7466739993542433e-10
# Finished epoch 999, loss:3.9381120586767793e-10

# %%
# Compute accuracy (no_grad is optional)
with torch.no_grad():
    y_pred = model(Xtensor)

 # We will estimate the error as a MSE function
 # between predictions and targets
error = torch.sum((y_pred - ytensor)**2)
print(f"Error {error}")
# Out:
# Error 2.646648056270351e-08

# %% [markdown]
# Once the model is trained, we can visualize the loss function during each epoch to see how the model is improving its learning. The variable `history` stores the information of the loss during the training process.

# %%
plt.figure()
plt.xlabel('Epoch')
plt.ylabel('Loss Magnitude')
plt.plot(history)
#plt.yscale('log')
plt.show()

# %% [markdown]
# From this plot it is possible to note that approximately from the epoch 300 or 400, the loss function is so small that it presents no substancial changes (i.e. from the epoch 400 the algorithm foes not learn anything more).

# %% [markdown]
# ---

# %% [markdown]
# ---
