# %% [markdown]
# ![Astrofisica Computacional](../logo.PNG)

# %% [markdown]
# ---
# ## 01. Sun and sunspots Images
#
#
# Eduard Larrañaga (ealarranaga@unal.edu.co)
#
# ---

# %% [markdown]
# ### Abstract
#
# In this notebook we generate some synthetic image of the Sun and radomly distributed sunspots.
#
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt


def genImg():
    fuz = 0.5
    image_data = np.ones([28,28])
    
    
    N = np.random.randint(6)
    i=0
    for x in range(28):
        for y in range(28):
            if (x-14)**2 + (y-14)**2 >= 100:
                image_data[x,y] = 0.8
                
    for x in range(28):
        for y in range(28):
            if (x-14)**2 + (y-14)**2 >= 121:
                image_data[x,y] = 0.6

    for x in range(28):
        for y in range(28):
            if (x-14)**2 + (y-14)**2 >= 144:
                image_data[x,y] = 0
                
    while i<N:
        x,y = np.random.randint(28, size=2)
        if (x-14)**2 + (y-14)**2 < 100:
            image_data[x,y] = 0
            image_data[x-1,y] = np.random.rand()*fuz+0.5
            image_data[x-1,y-1] = np.random.rand()*fuz+0.5
            image_data[x-1,y+1] = np.random.rand()*fuz+0.5
            image_data[x,y-1] = np.random.rand()*fuz+0.5
            image_data[x,y+1] = np.random.rand()*fuz+0.5
            image_data[x+1,y] = np.random.rand()*fuz+0.5
            image_data[x+1,y-1] = np.random.rand()*fuz+0.5
            image_data[x+1,y+1] = np.random.rand()*fuz+0.5
            i +=1
    
    return image_data, N


data, target = genImg()
print(target)
plt.figure(figsize=(2,2))
plt.imshow(data, cmap='gray')
plt.show()
# Out:
# 2

# %%
# Save training data
samples = 5000
data = np.zeros([samples,28,28])
targets = np.zeros(samples, dtype=int)
for j in range(samples):
    data[j], targets[j] = genImg()

np.save("sun_image_train.npy", data)
np.save("sun_label_train.npy", targets)
        
# Save test data
samples = 1000
data = np.zeros([samples,28,28])
targets = np.zeros(samples, dtype=int)
for j in range(samples):
    data[j], targets[j] = genImg()

np.save("sun_image_test.npy", data)
np.save("sun_label_test.npy", targets)

# %%
datos = np.load("sun_image_train.npy")
tar = np.load("sun_label_train.npy")

for i in range(len(tar)//2):
    print(tar[i])
    plt.figure(figsize=(2,2))
    plt.imshow(datos[i], cmap='gray')
    plt.show()
# Out:
# 1
# 5
# 2
# 3
# 0
# 4
# 0
# 4
# 0
# 2
# 3
# 3
# 1
# 2
# 3
# 5
# 2
# 1
# 1
# 3
# 1
# 1
# 4
# 0
# 0
# 0
# 3
# 2
# 5
# 4
# 1
# 0
# 3
# 2
# 1
# 1
# 0
# 3
# 3
# 3
# 0
# 0
# 2
# 5
# 0
# 2
# 2
# 3
# 4
# 4
# 3
# 5
# 5
# 5
# 4
# 3
# 2
# 5
# 4
# 2
# 0
# 0
# 3
# 2
# 3
# 4
# 1
# 1
# 3
# 5
# 2
# 0
# 3
# 3
# 3
# 2
# 5
# 4
# 3
# 0
# 0
# 0
# 1
# 3
# 2
# 1
# 3
# 0
# 4
# 0
# 2
# 2
# 3
# 3
# 0
# 0
# 3
# 2
# 4
# 2
# 2
# 5
# 4
# 4
# 4
# 4
# 3
# 5
# 1
# 5
# 2
# 3
# 1
# 3
# 4
# 3
# 0
# 1
# 1
# 4
# 0
# 4
# 5
# 5
# 1
# 4
# 5
# 0
# 5
# 1
# 5
# 3
# 5
# 3
# 1
# 1
# 4
# 5
# 1
# 2
# 0
# 4
# 5
# 1
# 5
# 3
# 2
# 4
# 1
# 2
# 5
# 3
# 3
# 3
# 5
# 1
# 0
# 3
# 5
# 2
# 5
# 1
# 1
# 4
# 4
# 1
# 3
# 5
# 1
# 1
# 2
# 3
# 4
# 0
# 0
# 3
# 1
# 0
# 4
# 5
# 5
# 3
# 4
# 5
# 0
# 4
# 5
# 0
# 3
# 4
# 5
# 3
# 5
# 5
# 0
# 2
# 1
# 4
# 2
# 1
# 0
# 4
# 5
# 3
# 1
# 4
# 3
# 1
# 1
# 2
# 2
# 1
# 2
# 1
# 1
# 3
# 3
# 2
# 1
# 0
# 1
# 1
# 5
# 5
# 4
# 0
# 1
# 2
# 5
# 5
# 4
# 5
# 1
# 5
# 2
# 0
# 4
# 4
# 0
# 1
# 3
# 1
# 4
# 1
# 0
# 5
# 2
# 0
# 5
# 5
# ...
