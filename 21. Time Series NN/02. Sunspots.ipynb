# %% [markdown]
# <center>
# <img src="https://i.ibb.co/ZVRt2f7/logo.png" alt="logo" border="0" width=800>

# %% [markdown]
# ---
#
# Eduard Larrañaga (ealarranaga@unal.edu.co)
#
# ---

# %% [markdown]
# ---
# # Neural Network modelling a Time Series.

# %% [markdown]
# The file 'ManchasSolares.txt' contains a dataset with the information of the monthly mean number of sunspots begining on january of 1749. We wan to train a neural network that predicts the mean number of sunspots using this information.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
# %matplotlib inline

# Reading the data
time, series = np.loadtxt('/content/drive/MyDrive/Colab Notebooks/Neural Networks/07. Time Series NN/ManchasSolares.txt', unpack=True)


plt.figure(figsize=(10,5))
plt.plot(time, series, color='black', linewidth=1)
plt.title('Mean number of sunspots per month')
plt.xlabel(r'month')
plt.ylabel(r'sunspots')
plt.grid()
plt.show()

# %% [markdown]
# ---
# ## Preprocessing the data
#
# In order to train the neural network, we will split the data set into training and test subsets. This time we will not split the set by taking randomly chosen data points. Instead, we will take the first 80% of the data to train the neural network and it will be used to predict the (future) behavior in the remaining 20% of the dataset.

# %%
# split data into validation and training datasets
split_time = int(len(time)*0.8)

time_train = time[:split_time]
x_train = series[:split_time]

time_test = time[split_time:]
x_test = series[split_time:]

# %%
x_train.shape, x_test.shape
# Out:
# ((2514,), (629,))

# %% [markdown]
# The idea is that the feature is a certain number of values in the series, while the label (or target) will be the next value. The number of values that we will treat as the feature will be called the **window size**. Hence, we said that we're taking a window of the data and training an ML model to predict the next value.
# For example, if we take our time series data 60 months at a time, we will use these 60 values as the feature and the next value is the label.

# %% [markdown]
# We will use the function [tensorflow.data.Dataset.from_tensor_slices()](https://www.tensorflow.org/api_docs/python/tf/data/Dataset#from_tensor_slices) to create a `dataset`from the series.
#
# The method [dataset.window()](https://www.tensorflow.org/api_docs/python/tf/data/Dataset#window) creates the windows (subsets of elements of the input dataset). The first argument in the method determines the size of each window. The `shift` argument determines the number of inputs elements to shift to start the next window.
# Finally, the `drop_remainder` argument is set to `True`, so that the last windows should be dropped if their size is smaller than the chosen `size`.
#
# The [dataset.flat_map()](https://www.tensorflow.org/api_docs/python/tf/data/Dataset#window) method is used to flatten the dataset of windows into a single dataset. The argument in this function is a function that takes the element from the dataset and returns a dataset. Then, the method chains together all the resulting datasets sequntially. Note that we use the [window.batch()](https://www.tensorflow.org/api_docs/python/tf/data/Dataset#batch) method in the function. This method combines consecutive elements of the dataset into batches with a size given by its argument.
#
# The method [dataset.shuffle()](https://www.tensorflow.org/api_docs/python/tf/data/Dataset#shuffle) will randomly shuffle the elements of the dataset. Here the dataset fills a buffer with `buffer_size elements, then randomly samples elements from this buffer, replacing the selected elements with new elements. For perfect shuffling, a buffer size greater than or equal to the full size of the dataset is required.
#
# The final step in this data preparation function is to use  the [window.batch()](https://www.tensorflow.org/api_docs/python/tf/data/Dataset#batch) function again and use the  method [.prefetch()](https://www.tensorflow.org/api_docs/python/tf/data/Dataset#prefetch) which allows later elements to be prepared while the current element is being processed. This improves latency and throughput, at the cost of using additional memory to store prefetched elements.

# %% [markdown]
# ---
#
# First we will try to define the windows.

# %%
# Observe the initial structure of the series:
series
# Out:
# array([58. , 62.6, 70. , ..., 25.2, 23.5, 21.6])

# %%
# Create the windows witha given size and 
# the windows are flattened into a single dataset

# Note the shift of 1 between each window

window_size = 60

dt = tf.data.Dataset.from_tensor_slices(series)
dt = dt.window(window_size + 1, shift=1, drop_remainder=True)
dt = dt.flat_map(lambda window: window.batch(window_size + 1))
list(dt.as_numpy_iterator())[0:5]
# Out:
# [array([ 58. ,  62.6,  70. ,  55.7,  85. ,  83.5,  94.8,  66.3,  75.9,
#          75.5, 158.6,  85.2,  73.3,  75.9,  89.2,  88.3,  90. , 100. ,
#          85.4, 103. ,  91.2,  65.7,  63.3,  75.4,  70. ,  43.5,  45.3,
#          56.4,  60.7,  50.7,  66.3,  59.8,  23.5,  23.2,  28.5,  44. ,
#          35. ,  50. ,  71. ,  59.3,  59.7,  39.6,  78.4,  29.3,  27.1,
#          46.6,  37.6,  40. ,  44. ,  32. ,  45.7,  38. ,  36. ,  31.7,
#          22. ,  39. ,  28. ,  25. ,  20. ,   6.7,   0. ]),
#  array([ 62.6,  70. ,  55.7,  85. ,  83.5,  94.8,  66.3,  75.9,  75.5,
#         158.6,  85.2,  73.3,  75.9,  89.2,  88.3,  90. , 100. ,  85.4,
#         103. ,  91.2,  65.7,  63.3,  75.4,  70. ,  43.5,  45.3,  56.4,
#          60.7,  50.7,  66.3,  59.8,  23.5,  23.2,  28.5,  44. ,  35. ,
#          50. ,  71. ,  59.3,  59.7,  39.6,  78.4,  29.3,  27.1,  46.6,
#          37.6,  40. ,  44. ,  32. ,  45.7,  38. ,  36. ,  31.7,  22. ,
#          39. ,  28. ,  25. ,  20. ,   6.7,   0. ,   3. ]),
#  array([ 70. ,  55.7,  85. ,  83.5,  94.8,  66.3,  75.9,  75.5, 158.6,
#          85.2,  73.3,  75.9,  89.2,  88.3,  90. , 100. ,  85.4, 103. ,
#          91.2,  65.7,  63.3,  75.4,  70. ,  43.5,  45.3,  56.4,  60.7,
#          50.7,  66.3,  59.8,  23.5,  23.2,  28.5,  44. ,  35. ,  50. ,
#          71. ,  59.3,  59.7,  39.6,  78.4,  29.3,  27.1,  46.6,  37.6,
#          40. ,  44. ,  32. ,  45.7,  38. ,  36. ,  31.7,  22. ,  39. ,
#          28. ,  25. ,  20. ,   6.7,   0. ,   3. ,   1.7]),
#  array([ 55.7,  85. ,  83.5,  94.8,  66.3,  75.9,  75.5, 158.6,  85.2,
#          73.3,  75.9,  89.2,  88.3,  90. , 100. ,  85.4, 103. ,  91.2,
#          65.7,  63.3,  75.4,  70. ,  43.5,  45.3,  56.4,  60.7,  50.7,
#          66.3,  59.8,  23.5,  23.2,  28.5,  44. ,  35. ,  50. ,  71. ,
#          59.3,  59.7,  39.6,  78.4,  29.3,  27.1,  46.6,  37.6,  40. ,
#          44. ,  32. ,  45.7,  38. ,  36. ,  31.7,  22. ,  39. ,  28. ,
#          25. ,  20. ,   6.7,   0. ,   3. ,   1.7,  13.7]),
#  array([ 85. ,  83.5,  94.8,  66.3,  75.9,  75.5, 158.6,  85.2,  73.3,
#          75.9,  89.2,  88.3,  90. , 100. ,  85.4, 103. ,  91.2,  65.7,
#          63.3,  75.4,  70. ,  43.5,  45.3,  56.4,  60.7,  50.7,  66.3,
#          59.8,  23.5,  23.2,  28.5,  44. ,  35. ,  50. ,  71. ,  59.3,
#          59.7,  39.6,  78.4,  29.3,  27.1,  46.6,  37.6,  40. ,  44. ,
#          32. ,  45.7,  38. ,  36. ,  31.7,  22. ,  39. ,  28. ,  25. ,
#          20. ,   6.7,   0. ,   3. ,   1.7,  13.7,  20.7])]

# %% [markdown]
# Note that each window has 61 elements. The first 60 are used as inputs while the last one is the corresponding label!!

# %% [markdown]
# Now, we will define a function that creates the windows and shuffle the information into batches.

# %%
# We define a function that turn a series into a dataset to train the 
# neural network

def windowed_dataset(series, window_size, batch_size, shuffle_buffer_size):
    # create the dataset from series
    dataset = tf.data.Dataset.from_tensor_slices(series)
    # slice the data up into appropriate windows
    dataset = dataset.window(window_size + 1, shift=1, drop_remainder=True)
    # flatten into chunks with a size of window size + 1
    dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))
    dataset = dataset.shuffle(shuffle_buffer_size).map(lambda window: (window[:-1], window[-1]))
    # batch into the selected batch_size and returned
    dataset = dataset.batch(batch_size).prefetch(1)
    return dataset


# Parameters
window_size = 60
batch_size = 32
shuffle_buffer_size = 1000

dataset = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer_size)

# %%
dataset
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, None), dtype=tf.float64, name=None), TensorSpec(shape=(None,), dtype=tf.float64, name=None))>

# %%
list(dataset.as_numpy_iterator())[0][0].shape
# Out:
# (32, 60)

# %%
list(dataset.as_numpy_iterator())[0][0][0]
# Out:
# array([ 7.9, 10.1,  0. , 10.3,  1.9, 16.6,  5.5, 11.2, 18.3,  8.4, 15.3,
#        27.8, 16.7, 14.3, 22.2, 12. ,  5.7, 23.8,  5.8, 14.9, 18.5,  2.3,
#         8.1, 19.3, 14.5, 20.1, 19.2, 32.2, 26.2, 31.6,  9.8, 55.9, 35.5,
#        47.2, 31.5, 33.5, 37.2, 65. , 26.3, 68.8, 73.7, 58.8, 44.3, 43.6,
#        38.8, 23.2, 47.8, 56.4, 38.1, 29.9, 36.4, 57.9, 96.2, 26.4, 21.2,
#        40. , 50. , 45. , 36.7, 25.6])

# %% [markdown]
# ## The Neural Network
#
# We will define a sequential neural network with an input layer with a number of neurons equal to the window size. Then, we use two hidden layers with 20 and 10 neurons and ReLU activation and an output layer with one layer. The loss function is the **M**ean **S**quared **E**rror (**MSE**) while the  optimizer will be [tf.keras.optimizers.SGD](https://keras.io/api/optimizers/sgd/). This algorithm uses gradient descent and momentum (which accelerates the gradient descent in the relevant direction and dampens oscillations).

# %%
# Two hidden layers and the output 
# Input shape is the size of window 

model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(128, activation="relu", input_shape=[window_size]),
    tf.keras.layers.Dense(128, activation="relu"),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(128, activation="relu"),
    tf.keras.layers.Dense(1)
    ])

model.compile(loss="mse", 
              optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
              metrics=[tf.keras.metrics.MeanAbsoluteError()])


history = model.fit(dataset,epochs=100)

model.summary()
# Out:
# Epoch 1/100
# 77/77 [==============================] - 4s 17ms/step - loss: 597.7070 - mean_absolute_error: 17.2743
# Epoch 2/100
# 77/77 [==============================] - 1s 13ms/step - loss: 410.2188 - mean_absolute_error: 14.5333
# Epoch 3/100
# 77/77 [==============================] - 1s 7ms/step - loss: 353.2163 - mean_absolute_error: 13.4703
# Epoch 4/100
# 77/77 [==============================] - 1s 8ms/step - loss: 347.3849 - mean_absolute_error: 13.2618
# Epoch 5/100
# 77/77 [==============================] - 1s 12ms/step - loss: 315.9636 - mean_absolute_error: 12.5168
# Epoch 6/100
# 77/77 [==============================] - 1s 14ms/step - loss: 308.3477 - mean_absolute_error: 12.5812
# Epoch 7/100
# 77/77 [==============================] - 1s 8ms/step - loss: 295.6767 - mean_absolute_error: 12.3204
# Epoch 8/100
# 77/77 [==============================] - 1s 8ms/step - loss: 273.9775 - mean_absolute_error: 11.8372
# Epoch 9/100
# 77/77 [==============================] - 1s 6ms/step - loss: 280.3784 - mean_absolute_error: 11.9022
# Epoch 10/100
# 77/77 [==============================] - 1s 11ms/step - loss: 288.1771 - mean_absolute_error: 12.0353
# Epoch 11/100
# 77/77 [==============================] - 2s 16ms/step - loss: 285.6209 - mean_absolute_error: 11.9042
# Epoch 12/100
# 77/77 [==============================] - 1s 8ms/step - loss: 263.0630 - mean_absolute_error: 11.5059
# Epoch 13/100
# 77/77 [==============================] - 1s 7ms/step - loss: 269.7760 - mean_absolute_error: 11.5957
# Epoch 14/100
# 77/77 [==============================] - 1s 6ms/step - loss: 261.8885 - mean_absolute_error: 11.4622
# Epoch 15/100
# 77/77 [==============================] - 1s 7ms/step - loss: 265.3290 - mean_absolute_error: 11.6617
# Epoch 16/100
# 77/77 [==============================] - 1s 7ms/step - loss: 256.5101 - mean_absolute_error: 11.4859
# Epoch 17/100
# 77/77 [==============================] - 1s 6ms/step - loss: 244.1609 - mean_absolute_error: 11.1559
# Epoch 18/100
# 77/77 [==============================] - 1s 7ms/step - loss: 249.9980 - mean_absolute_error: 11.2215
# Epoch 19/100
# 77/77 [==============================] - 1s 8ms/step - loss: 244.2429 - mean_absolute_error: 11.1532
# Epoch 20/100
# 77/77 [==============================] - 1s 8ms/step - loss: 244.4987 - mean_absolute_error: 11.0668
# Epoch 21/100
# 77/77 [==============================] - 1s 14ms/step - loss: 231.3274 - mean_absolute_error: 10.8850
# Epoch 22/100
# 77/77 [==============================] - 1s 8ms/step - loss: 249.8083 - mean_absolute_error: 11.2293
# Epoch 23/100
# 77/77 [==============================] - 1s 9ms/step - loss: 247.1514 - mean_absolute_error: 11.0920
# Epoch 24/100
# 77/77 [==============================] - 1s 8ms/step - loss: 228.3323 - mean_absolute_error: 10.9033
# Epoch 25/100
# 77/77 [==============================] - 1s 7ms/step - loss: 253.0392 - mean_absolute_error: 11.3163
# Epoch 26/100
# 77/77 [==============================] - 1s 7ms/step - loss: 233.6290 - mean_absolute_error: 10.9418
# Epoch 27/100
# 77/77 [==============================] - 1s 8ms/step - loss: 245.3479 - mean_absolute_error: 11.1096
# Epoch 28/100
# 77/77 [==============================] - 1s 7ms/step - loss: 223.2084 - mean_absolute_error: 10.6077
# Epoch 29/100
# 77/77 [==============================] - 1s 7ms/step - loss: 235.8647 - mean_absolute_error: 10.9043
# Epoch 30/100
# 77/77 [==============================] - 2s 17ms/step - loss: 234.2020 - mean_absolute_error: 10.9220
# Epoch 31/100
# 77/77 [==============================] - 1s 15ms/step - loss: 227.6950 - mean_absolute_error: 10.7922
# Epoch 32/100
# 77/77 [==============================] - 2s 16ms/step - loss: 223.0593 - mean_absolute_error: 10.7272
# Epoch 33/100
# 77/77 [==============================] - 1s 8ms/step - loss: 222.5530 - mean_absolute_error: 10.6735
# Epoch 34/100
# 77/77 [==============================] - 1s 8ms/step - loss: 224.0602 - mean_absolute_error: 10.6448
# Epoch 35/100
# 77/77 [==============================] - 1s 7ms/step - loss: 218.8551 - mean_absolute_error: 10.4713
# Epoch 36/100
# 77/77 [==============================] - 1s 7ms/step - loss: 227.6750 - mean_absolute_error: 10.7754
# Epoch 37/100
# 77/77 [==============================] - 1s 8ms/step - loss: 212.7428 - mean_absolute_error: 10.5198
# Epoch 38/100
# 77/77 [==============================] - 1s 7ms/step - loss: 211.8944 - mean_absolute_error: 10.4392
# Epoch 39/100
# 77/77 [==============================] - 1s 8ms/step - loss: 221.0465 - mean_absolute_error: 10.6216
# Epoch 40/100
# 77/77 [==============================] - 1s 9ms/step - loss: 220.1509 - mean_absolute_error: 10.4201
# Epoch 41/100
# 77/77 [==============================] - 2s 16ms/step - loss: 210.4704 - mean_absolute_error: 10.4318
# Epoch 42/100
# 77/77 [==============================] - 1s 10ms/step - loss: 215.2972 - mean_absolute_error: 10.3980
# Epoch 43/100
# 77/77 [==============================] - 1s 8ms/step - loss: 208.9872 - mean_absolute_error: 10.3580
# Epoch 44/100
# 77/77 [==============================] - 1s 7ms/step - loss: 203.5740 - mean_absolute_error: 10.2474
# Epoch 45/100
# 77/77 [==============================] - 1s 6ms/step - loss: 213.3158 - mean_absolute_error: 10.5757
# Epoch 46/100
# 77/77 [==============================] - 1s 7ms/step - loss: 209.4342 - mean_absolute_error: 10.4280
# Epoch 47/100
# 77/77 [==============================] - 1s 8ms/step - loss: 201.5046 - mean_absolute_error: 10.1250
# Epoch 48/100
# 77/77 [==============================] - 1s 8ms/step - loss: 210.0425 - mean_absolute_error: 10.4668
# Epoch 49/100
# 77/77 [==============================] - 1s 6ms/step - loss: 210.9113 - mean_absolute_error: 10.1704
# Epoch 50/100
# 77/77 [==============================] - 1s 7ms/step - loss: 200.8460 - mean_absolute_error: 10.0751
# Epoch 51/100
# 77/77 [==============================] - 1s 7ms/step - loss: 194.0070 - mean_absolute_error: 9.9982
# Epoch 52/100
# 77/77 [==============================] - 2s 16ms/step - loss: 192.3712 - mean_absolute_error: 10.0618
# Epoch 53/100
# 77/77 [==============================] - 2s 16ms/step - loss: 195.7376 - mean_absolute_error: 10.0502
# Epoch 54/100
# 77/77 [==============================] - 1s 7ms/step - loss: 210.9976 - mean_absolute_error: 10.4502
# Epoch 55/100
# 77/77 [==============================] - 1s 6ms/step - loss: 196.4824 - mean_absolute_error: 10.0335
# Epoch 56/100
# 77/77 [==============================] - 1s 7ms/step - loss: 187.2300 - mean_absolute_error: 9.6923
# Epoch 57/100
# 77/77 [==============================] - 1s 8ms/step - loss: 192.6348 - mean_absolute_error: 10.0648
# Epoch 58/100
# 77/77 [==============================] - 1s 7ms/step - loss: 188.5581 - mean_absolute_error: 9.9589
# Epoch 59/100
# 77/77 [==============================] - 1s 7ms/step - loss: 190.0746 - mean_absolute_error: 9.8923
# Epoch 60/100
# 77/77 [==============================] - 1s 7ms/step - loss: 182.1892 - mean_absolute_error: 9.7479
# Epoch 61/100
# 77/77 [==============================] - 1s 7ms/step - loss: 180.0102 - mean_absolute_error: 9.6383
# Epoch 62/100
# 77/77 [==============================] - 1s 14ms/step - loss: 178.4277 - mean_absolute_error: 9.5497
# Epoch 63/100
# 77/77 [==============================] - 2s 16ms/step - loss: 185.8084 - mean_absolute_error: 9.8923
# Epoch 64/100
# 77/77 [==============================] - 1s 6ms/step - loss: 176.5378 - mean_absolute_error: 9.5551
# Epoch 65/100
# 77/77 [==============================] - 1s 7ms/step - loss: 195.4343 - mean_absolute_error: 9.9501
# Epoch 66/100
# 77/77 [==============================] - 1s 8ms/step - loss: 194.5248 - mean_absolute_error: 9.8581
# Epoch 67/100
# 77/77 [==============================] - 1s 8ms/step - loss: 174.2223 - mean_absolute_error: 9.4946
# Epoch 68/100
# 77/77 [==============================] - 1s 8ms/step - loss: 169.6974 - mean_absolute_error: 9.4150
# Epoch 69/100
# 77/77 [==============================] - 1s 8ms/step - loss: 173.4536 - mean_absolute_error: 9.5287
# Epoch 70/100
# 77/77 [==============================] - 1s 8ms/step - loss: 170.7414 - mean_absolute_error: 9.4432
# Epoch 71/100
# 77/77 [==============================] - 1s 8ms/step - loss: 171.5801 - mean_absolute_error: 9.4460
# Epoch 72/100
# 77/77 [==============================] - 1s 13ms/step - loss: 169.9608 - mean_absolute_error: 9.3954
# Epoch 73/100
# 77/77 [==============================] - 2s 16ms/step - loss: 165.2429 - mean_absolute_error: 9.1462
# Epoch 74/100
# 77/77 [==============================] - 1s 8ms/step - loss: 174.6811 - mean_absolute_error: 9.4296
# Epoch 75/100
# 77/77 [==============================] - 1s 7ms/step - loss: 161.9318 - mean_absolute_error: 9.2367
# Epoch 76/100
# 77/77 [==============================] - 1s 7ms/step - loss: 155.2600 - mean_absolute_error: 8.9654
# Epoch 77/100
# 77/77 [==============================] - 1s 12ms/step - loss: 153.1459 - mean_absolute_error: 9.0327
# Epoch 78/100
# 77/77 [==============================] - 1s 7ms/step - loss: 149.1648 - mean_absolute_error: 8.8144
# Epoch 79/100
# 77/77 [==============================] - 1s 8ms/step - loss: 168.3134 - mean_absolute_error: 9.3375
# Epoch 80/100
# 77/77 [==============================] - 1s 8ms/step - loss: 157.5428 - mean_absolute_error: 9.2398
# Epoch 81/100
# 77/77 [==============================] - 1s 7ms/step - loss: 149.6791 - mean_absolute_error: 9.0226
# Epoch 82/100
# 77/77 [==============================] - 1s 15ms/step - loss: 141.6943 - mean_absolute_error: 8.7791
# Epoch 83/100
# 77/77 [==============================] - 1s 15ms/step - loss: 153.5475 - mean_absolute_error: 8.9253
# Epoch 84/100
# 77/77 [==============================] - 1s 7ms/step - loss: 145.9715 - mean_absolute_error: 8.7296
# Epoch 85/100
# 77/77 [==============================] - 1s 8ms/step - loss: 148.6101 - mean_absolute_error: 8.8586
# Epoch 86/100
# 77/77 [==============================] - 1s 8ms/step - loss: 145.4074 - mean_absolute_error: 8.8002
# Epoch 87/100
# 77/77 [==============================] - 1s 7ms/step - loss: 152.7333 - mean_absolute_error: 8.8980
# Epoch 88/100
# 77/77 [==============================] - 1s 8ms/step - loss: 152.6203 - mean_absolute_error: 9.0404
# Epoch 89/100
# 77/77 [==============================] - 1s 7ms/step - loss: 133.6537 - mean_absolute_error: 8.4533
# Epoch 90/100
# 77/77 [==============================] - 1s 7ms/step - loss: 136.7740 - mean_absolute_error: 8.4740
# Epoch 91/100
# 77/77 [==============================] - 1s 7ms/step - loss: 128.5396 - mean_absolute_error: 8.2557
# Epoch 92/100
# 77/77 [==============================] - 2s 16ms/step - loss: 130.8136 - mean_absolute_error: 8.3919
# Epoch 93/100
# 77/77 [==============================] - 1s 14ms/step - loss: 130.7812 - mean_absolute_error: 8.3392
# Epoch 94/100
# 77/77 [==============================] - 1s 8ms/step - loss: 131.3480 - mean_absolute_error: 8.2894
# Epoch 95/100
# 77/77 [==============================] - 1s 7ms/step - loss: 120.8667 - mean_absolute_error: 8.1773
# Epoch 96/100
# 77/77 [==============================] - 1s 8ms/step - loss: 121.7268 - mean_absolute_error: 8.1085
# Epoch 97/100
# 77/77 [==============================] - 1s 6ms/step - loss: 132.0557 - mean_absolute_error: 8.4365
# Epoch 98/100
# 77/77 [==============================] - 1s 17ms/step - loss: 124.3487 - mean_absolute_error: 8.1577
# Epoch 99/100
# 77/77 [==============================] - 1s 15ms/step - loss: 122.7186 - mean_absolute_error: 8.0688
# Epoch 100/100
# 77/77 [==============================] - 2s 15ms/step - loss: 136.3393 - mean_absolute_error: 8.3818
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_57 (Dense)            (None, 128)               7808
#
#  dense_58 (Dense)            (None, 128)               16512
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_59 (Dense)            (None, 128)               16512
#
#  dense_60 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 40,961
# Trainable params: 40,961
# Non-trainable params: 0
# _________________________________________________________________

# %%
#model.save('/content/drive/MyDrive/Colab Notebooks/Neural Networks/07. Time Series NN/model01')
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.

# %%
recovered_model = tf.keras.models.load_model('/content/drive/MyDrive/Colab Notebooks/Neural Networks/07. Time Series NN/model01')

# %%
loss = history.history['loss']
epochs = range(len(loss))

plt.figure(figsize=(5,4))
plt.plot(epochs, loss, 'b', label='Training Loss')
plt.xlabel('epoch')
plt.ylabel('Loss function')
plt.show()

# %%
forecast=[]

for time in range(split_time - window_size, len(series) - window_size):
    forecast.append(model.predict(series[time:time + window_size][np.newaxis], verbose=False))

results = np.array(forecast)[:, 0, 0]

# %%
plt.figure(figsize=(7, 4))
plt.plot(time_test, results, c = 'crimson', label='NN prediction')
plt.plot(time_test, x_test, label='data', alpha=0.5)

plt.title('Sunspots mean per month')
plt.xlabel(r'month')
plt.ylabel(r'sunspots')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# In order to measure the accuracy of the algorithm, we will use the [**M**ean **A**bsolute **E**rror](https://keras.io/api/metrics/regression_metrics/#meanabsoluteerror-class) (**MAE**) metric

# %%
tf.keras.metrics.mean_absolute_error(x_test, results).numpy()
# Out:
# 13.9455595
